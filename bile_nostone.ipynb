# %% [markdown]
# # Prediction of bile predicaments

# %%
import pandas as pd

import numpy as np

from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow_decision_forests as tfdf

from sklearn.model_selection import train_test_split

import tensorflow_decision_forests as tfdf

import dtreeviz

from matplotlib import pyplot as plt
from IPython import display

# avoid "Arial font not found warnings"
import logging
logging.getLogger('matplotlib.font_manager').setLevel(level=logging.CRITICAL)

display.set_matplotlib_formats('retina') # generate hires plots

np.random.seed(1234)  # reproducible plots_data for explanatory reasons
# Out:
# 2023-12-18 16:53:13.280749: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 16:53:13.304004: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-18 16:53:13.304032: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-18 16:53:13.304668: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-12-18 16:53:13.308384: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-12-18 16:53:13.309042: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-12-18 16:53:13.972593: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /tmp/ipykernel_34671/3521166008.py:26: DeprecationWarning: `set_matplotlib_formats` is deprecated since IPython 7.23, directly use `matplotlib_inline.backend_inline.set_matplotlib_formats()`

# %% [markdown]
# ## Get & clean data

# %% [markdown]
# ### Load and inspect

# %%
df_idc = pd.read_excel("data/Intraductal_concrement.xlsx", sheet_name=0, skiprows=1, header=None)
df_idc_visits = pd.read_excel("data/Intraductal_concrement.xlsx", sheet_name=0, skiprows=0, header=None)
df_idc.columns = df_idc_visits.iloc[0] + '_' + df_idc.iloc[0]
df_idc.columns = df_idc.columns.str.lower()
df_idc.insert(2, 'has_idc', "1")
df_idc.drop(index=0, inplace=True)

# %%
df_idc.iloc[:, 2:]
# Out:
# 0   has_idc baseline_characteristics_etiology  \
# 1         1                           biliary
# 2         1                           biliary
# 3         1                           biliary
# 4         1                           biliary
# 5         1                           biliary
# ..      ...                               ...
# 163       1                           biliary
# 164       1                           biliary
# 165       1                           biliary
# 166       1                           biliary
# 167       1                           biliary
#
# 0   baseline_characteristics_admission_date baseline_characteristics_age  \
# 1                       2012-04-07 00:00:00                           91
# 2                       2010-05-18 00:00:00                           68
# 3                       2006-10-15 00:00:00                           72
# 4                       2006-10-01 00:00:00                           66
# 5                       2021-02-08 00:00:00                           81
# ..                                      ...                          ...
# 163                     2006-04-28 00:00:00                           69
# 164                     2018-10-29 00:00:00                           65
# 165                     2017-12-01 00:00:00                           60
# 166                     2018-12-29 00:00:00                           54
# 167                     2018-04-26 00:00:00                           74
#
# 0   baseline_characteristics_sex baseline_characteristics_height_in_cm  \
# 1                              f                               unknown
# 2                              f                                   176
# 3                              f                                   160
# 4                              f                                   165
# 5                              f                                   172
# ..                           ...                                   ...
# 163                            m                                   169
# 164                            f                                   161
# 165                            m                                   176
# 166                            f                                   156
# 167                            m                                   186
#
# 0   baseline_characteristics_weight_in_kg baseline_characteristics_bmi  \
# 1                                 unknown                      unknown
# 2                                      74                         23.9
# 3                                      72                         28.1
# 4                                      52                         19.1
# 5                                      74                           25
# ..                                    ...                          ...
# 163                                    75                         26.3
# 164                                    73                         28.2
# 165                                   115                         37.1
# 166                                    81                         33.3
# 167                                   104                         30.1
#
# 0   baseline_characteristics_medical_history  \
# 1                                    1,4,5,9
# 2                                          5
# 3                                    1,4,7,9
# 4                                      1,3,9
# 5                                        1.9
# ..                                       ...
# 163                                3,4,7,8,9
# 164                                        0
# 165                                        9
# 166                                        9
# 167                                      5.9
#
# 0   baseline_characteristics_medication_at_admission  ...  \
# 1                                              1,2,4  ...
# 2                                                  0  ...
# 3                                            1,2,3,4  ...
# 4                                            1,2,4,8  ...
# 5                                                2.7  ...
# ..                                               ...  ...
# 163                                              1.2  ...
# 164                                                0  ...
# 165                                              1.2  ...
# 166                                          unknown  ...
# 167                                                2  ...
#
# 0   abdominal_sonography_size_of_smallest_concrement  \
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# ..                                               ...
# 163                                              NaN
# 164                                              NaN
# 165                                              NaN
# 166                                          unknown
# 167                                                4
#
# 0   abdominal_sonography_size_of_biggest_concrement  \
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# ..                                              ...
# 163                                             2.5
# 164                                               6
# 165                                               5
# 166                                         unknown
# 167                                            10.3
#
# 0   abdominal_sonography_ultrasound_behaviour  \
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# ..                                        ...
# 163       hyperechoic_with_acoustic_shadowing
# 164       hyperechoic_with_acoustic_shadowing
# 165                                   unknown
# 166                                   unknown
# 167                               hyperechoic
#
# 0   eus_ercp_mrcp_or_as_dhc_width_in_mm   NaN  \
# 1                                     8   EUS
# 2                                    15  ERCP
# 3                                    15    CT
# 4                                    15  ERCP
# 5                                    12    AS
# ..                                  ...   ...
# 163                                   8    AS
# 164                                 9.5   EUS
# 165                                  11    AS
# 166                             unknown   NaN
# 167                                   6   EUS
#
# 0   eus_ercp_mrcp_or_as_intrahepatic_bile_duct_width_in_mm  NaN  NaN  \
# 1                                                  NaN      NaN   CT
# 2                                                  NaN      NaN  NaN
# 3                                                  NaN      NaN   CT
# 4                                                  NaN      NaN  NaN
# 5                                                  NaN      NaN  NaN
# ..                                                 ...      ...  ...
# 163                                                NaN      NaN   CT
# 164                                                NaN      NaN   CT
# 165                                                NaN      NaN   CT
# 166                                                NaN      NaN   CT
# 167                                                NaN      NaN  NaN
#
# 0            ct/mri_date                             ct/mri_special_report?
# 1    2012-04-07 00:00:00                               peripancreatic_fluid
# 2                    NaN                                                NaN
# 3    2006-10-16 00:00:00                                     no_concrements
# 4                    NaN                                                NaN
# 5                    NaN                                                NaN
# ..                   ...                                                ...
# 163  2006-04-28 00:00:00                 perpancreatic_fluid;no_concrements
# 164  2018-10-29 00:00:00  GB:_41x27mm_concrement+15-20_concrements_about...
# 165  2017-12-02 00:00:00     2_small_concrements_in_GB;peripancreatic_fluid
# 166  2018-12-30 00:00:00                      concrements_and_sludge_in_DHC
# 167                  NaN                                                NaN
#
# [167 rows x 151 columns]

# %%
df_idc.columns.tolist()[:10]
# Out:
# ['baseline_characteristics_patient_number',
#  'baseline_characteristics_case',
#  'has_idc',
#  'baseline_characteristics_etiology',
#  'baseline_characteristics_admission_date',
#  'baseline_characteristics_age',
#  'baseline_characteristics_sex',
#  'baseline_characteristics_height_in_cm',
#  'baseline_characteristics_weight_in_kg',
#  'baseline_characteristics_bmi']

# %%
df_no_idc = pd.read_excel("data/No_intraductal_concrement.xlsx", sheet_name=0, skiprows=1, header=None)
df_no_idc_visits = pd.read_excel("data/No_intraductal_concrement.xlsx", sheet_name=0, skiprows=0, header=None)
df_no_idc.columns = df_no_idc_visits.iloc[0] + '_' + df_no_idc.iloc[0]
df_no_idc.columns = df_no_idc.columns.str.lower()
df_no_idc.insert(2, 'has_idc', "0")
df_no_idc.drop(index=0, inplace=True)

# %%
df_no_idc.iloc[:, 2:]
# Out:
# 0   has_idc baseline_characteristics_etiology  \
# 1         0                           biliary
# 2         0                           biliary
# 3         0                           biliary
# 4         0                           biliary
# 5         0                           biliary
# ..      ...                               ...
# 177       0                           biliary
# 178       0                           biliary
# 179       0                           biliary
# 180       0                           biliary
# 181       0                           biliary
#
# 0   baseline_characteristics_admission_date baseline_characteristics_age  \
# 1                       2006-11-21 00:00:00                           69
# 2                       2017-07-23 00:00:00                           81
# 3                       2006-05-14 00:00:00                           67
# 4                       2016-01-21 00:00:00                           80
# 5                       2020-12-25 00:00:00                           87
# ..                                      ...                          ...
# 177                     2013-04-29 00:00:00                           43
# 178                     2012-01-22 00:00:00                           83
# 179                     2018-08-24 00:00:00                           55
# 180                     2011-12-23 00:00:00                           49
# 181                     2013-06-09 00:00:00                           40
#
# 0   baseline_characteristics_sex baseline_characteristics_height_in_cm  \
# 1                              m                                   177
# 2                              f                                   160
# 3                              f                                   166
# 4                              m                                   165
# 5                              f                                   163
# ..                           ...                                   ...
# 177                            m                                   183
# 178                            m                                   180
# 179                            f                                   161
# 180                            m                                   180
# 181                            f                                   170
#
# 0   baseline_characteristics_weight_in_kg baseline_characteristics_bmi  \
# 1                                      76                         24.3
# 2                                    84.6                         33.2
# 3                                      70                         25.4
# 4                                      70                         25.7
# 5                                      86                         32.4
# ..                                    ...                          ...
# 177                                    93                         27.8
# 178                                    85                         26.2
# 179                                  66.3                         25.6
# 180                                    86                         26.5
# 181                                    69                         23.9
#
# 0   baseline_characteristics_medical_history  \
# 1                                          8
# 2                                          9
# 3                                        2.5
# 4                                    1,4,7,9
# 5                                    4,5,8,9
# ..                                       ...
# 177                                        5
# 178                                        9
# 179                                        0
# 180                                        0
# 181                                        0
#
# 0   baseline_characteristics_medication_at_admission  ...  \
# 1                                                  0  ...
# 2                                              1,2,8  ...
# 3                                                  0  ...
# 4                                              1,2,3  ...
# 5                                            1,2,3,4  ...
# ..                                               ...  ...
# 177                                                1  ...
# 178                                              2.3  ...
# 179                                              1.2  ...
# 180                                                0  ...
# 181                                                0  ...
#
# 0   abdominal_sonography_size_of_smallest_concrement  \
# 1                                            unknown
# 2                                                NaN
# 3                                                 22
# 4                                                NaN
# 5                                            unknown
# ..                                               ...
# 177                                              NaN
# 178                                          unknown
# 179                                          unknown
# 180                                          unknown
# 181                                              NaN
#
# 0   abdominal_sonography_size_of_biggest_concrement  \
# 1                                           unknown
# 2                                                16
# 3                                                30
# 4                                               NaN
# 5                                           unknown
# ..                                              ...
# 177                                               6
# 178                                         unknown
# 179                                         unknown
# 180                                         unknown
# 181                                              17
#
# 0   abdominal_sonography_ultrasound_behaviour  \
# 1         hyperechoic_with_acoustic_shadowing
# 2         hyperechoic_with_acoustic_shadowing
# 3         hyperechoic_with_acoustic_shadowing
# 4                                         NaN
# 5                                     unknown
# ..                                        ...
# 177                                   unknown
# 178                                   unknown
# 179                                   unknown
# 180       hyperechoic_with_acoustic_shadowing
# 181       hyperechoic_with_acoustic_shadowing
#
# 0   eus_ercp_mrcp_or_as_dhc_width_in_mm   NaN  \
# 1                               unknown   NaN
# 2                                     9   EUS
# 3                                    10    CT
# 4                                    13  ERCP
# 5                               unknown   NaN
# ..                                  ...   ...
# 177                                   5    AS
# 178                             unknown   NaN
# 179                             unknown   NaN
# 180                                  15  MRCP
# 181                                 3.7    AS
#
# 0   eus_ercp_mrcp_or_as_intrahepatic_bile_duct_width_in_mm  NaN  NaN  \
# 1                                                  NaN      NaN   CT
# 2                                                  NaN      NaN  NaN
# 3                                                  NaN      NaN   CT
# 4                                                  NaN      NaN   CT
# 5                                                  NaN      NaN   CT
# ..                                                 ...      ...  ...
# 177                                                NaN      NaN   CT
# 178                                                NaN      NaN  NaN
# 179                                                NaN      NaN  NaN
# 180                                                NaN      NaN  NaN
# 181                                                NaN      NaN  NaN
#
# 0            ct/mri_date                             ct/mri_special_report?
# 1    2006-11-21 00:00:00               2-3_concrements_(ca.0,6cm)_in_the_GB
# 2                    NaN                                                NaN
# 3    2006-05-14 00:00:00  concrements_in_the_GB;peripancreatic_adipose_t...
# 4    2016-01-21 00:00:00                   prepapillary_concrement_ca.8,5mm
# 5    2020-12-30 00:00:00                                   GB_not_mentioned
# ..                   ...                                                ...
# 177  2013-04-29 00:00:00                                     no_concrements
# 178                  NaN                                                NaN
# 179                  NaN                                                NaN
# 180                  NaN                                                NaN
# 181                  NaN                                                NaN
#
# [181 rows x 151 columns]

# %%
df_no_idc.columns.tolist()[:10]
# Out:
# ['baseline_characteristics_patient_number',
#  'baseline_characteristics_case',
#  'has_idc',
#  'baseline_characteristics_etiology',
#  'baseline_characteristics_admission_date',
#  'baseline_characteristics_age',
#  'baseline_characteristics_sex',
#  'baseline_characteristics_height_in_cm',
#  'baseline_characteristics_weight_in_kg',
#  'baseline_characteristics_bmi']

# %% [markdown]
# ### Check that column names are identical

# %%
assert(df_idc.columns.tolist() == df_no_idc.columns.tolist())

# %% [markdown]
# ### Join the data frames

# %%
input_data = pd.concat([df_idc, df_no_idc])

# %% [markdown]
# ### Clean and format

# %%
input_data.replace(['unknown', 'missing', 'ns', ' ns', "ms", "s", "sn"], np.nan, inplace=True)
lab_cols = input_data.filter(like='lab_values').columns
input_data[lab_cols] = input_data[lab_cols].replace(',', '.', regex=True)
input_data[lab_cols] = input_data[lab_cols].replace(['.*\\.\\..*', '.*\\.\\.\\..*'], pd.NA, regex=True)
input_data[lab_cols] = input_data[lab_cols].replace('ß', '0', regex=True)
input_data[lab_cols] = input_data[lab_cols].replace('.', np.nan)
input_data[lab_cols] = input_data[lab_cols].replace('n2.23', np.nan)

# %%
input_data[['ercp_date', 'baseline_characteristics_admission_date']] = input_data[['ercp_date', 'baseline_characteristics_admission_date']].replace(['.*\\.\\..*', '.*\\.\\.\\..*'], pd.NA, regex=True)

input_data = input_data.convert_dtypes()
input_data[lab_cols] = input_data[lab_cols].astype('float64')

# Add column if ercp_date was within 3 days of admission baseline_characteristics_admission_date
input_data['ercp_date'] = pd.to_datetime(input_data['ercp_date'])
input_data['baseline_characteristics_admission_date'] = pd.to_datetime(input_data['baseline_characteristics_admission_date'])
input_data['ercp_date_minus_admission_date'] = input_data['ercp_date'] - input_data['baseline_characteristics_admission_date']
input_data['ecrp_gte_3_days_naT'] = input_data['ercp_date_minus_admission_date'] >= pd.Timedelta(days=3) 
input_data['ercp_date_na'] = input_data['ercp_date'].isna()
input_data['ecrp_gte_3_days'] =  input_data['ercp_date_na'] | input_data['ecrp_gte_3_days_naT']

# Rename column names of input_data
input_data.columns = input_data.columns.str.replace('/', '_')
input_data.columns = input_data.columns.str.replace(' ', '')

# %%
input_data.iloc[:, 2:]
# Out:
# 0   has_idc baseline_characteristics_etiology  \
# 1         1                           biliary
# 2         1                           biliary
# 3         1                           biliary
# 4         1                           biliary
# 5         1                           biliary
# ..      ...                               ...
# 177       0                           biliary
# 178       0                           biliary
# 179       0                           biliary
# 180       0                           biliary
# 181       0                           biliary
#
# 0   baseline_characteristics_admission_date  baseline_characteristics_age  \
# 1                                2012-04-07                            91
# 2                                2010-05-18                            68
# 3                                2006-10-15                            72
# 4                                2006-10-01                            66
# 5                                2021-02-08                            81
# ..                                      ...                           ...
# 177                              2013-04-29                            43
# 178                              2012-01-22                            83
# 179                              2018-08-24                            55
# 180                              2011-12-23                            49
# 181                              2013-06-09                            40
#
# 0   baseline_characteristics_sex  baseline_characteristics_height_in_cm  \
# 1                              f                                   <NA>
# 2                              f                                    176
# 3                              f                                    160
# 4                              f                                    165
# 5                              f                                    172
# ..                           ...                                    ...
# 177                            m                                    183
# 178                            m                                    180
# 179                            f                                    161
# 180                            m                                    180
# 181                            f                                    170
#
# 0   baseline_characteristics_weight_in_kg  baseline_characteristics_bmi  \
# 1                                     NaN                          <NA>
# 2                                      74                          23.9
# 3                                      72                          28.1
# 4                                      52                          19.1
# 5                                      74                          25.0
# ..                                    ...                           ...
# 177                                    93                          27.8
# 178                                    85                          26.2
# 179                                  66.3                          25.6
# 180                                    86                          26.5
# 181                                    69                          23.9
#
# 0   baseline_characteristics_medical_history  \
# 1                                    1,4,5,9
# 2                                          5
# 3                                    1,4,7,9
# 4                                      1,3,9
# 5                                        1.9
# ..                                       ...
# 177                                        5
# 178                                        9
# 179                                        0
# 180                                        0
# 181                                        0
#
# 0   baseline_characteristics_medication_at_admission  ...   NaN  \
# 1                                              1,2,4  ...   EUS
# 2                                                  0  ...  ERCP
# 3                                            1,2,3,4  ...    CT
# 4                                            1,2,4,8  ...  ERCP
# 5                                                2.7  ...    AS
# ..                                               ...  ...   ...
# 177                                                1  ...    AS
# 178                                              2.3  ...  <NA>
# 179                                              1.2  ...  <NA>
# 180                                                0  ...  MRCP
# 181                                                0  ...    AS
#
# 0    eus_ercp_mrcp_or_as_intrahepatic_bile_duct_width_in_mm   NaN   NaN  \
# 1                                                 <NA>       <NA>    CT
# 2                                                 <NA>       <NA>  <NA>
# 3                                                 <NA>       <NA>    CT
# 4                                                 <NA>       <NA>  <NA>
# 5                                                 <NA>       <NA>  <NA>
# ..                                                 ...        ...   ...
# 177                                               <NA>       <NA>    CT
# 178                                               <NA>       <NA>  <NA>
# 179                                               <NA>       <NA>  <NA>
# 180                                               <NA>       <NA>  <NA>
# 181                                               <NA>       <NA>  <NA>
#
# 0            ct_mri_date  ct_mri_special_report?  \
# 1    2012-04-07 00:00:00    peripancreatic_fluid
# 2                    NaN                    <NA>
# 3    2006-10-16 00:00:00          no_concrements
# 4                    NaN                    <NA>
# 5                    NaN                    <NA>
# ..                   ...                     ...
# 177  2013-04-29 00:00:00          no_concrements
# 178                  NaN                    <NA>
# 179                  NaN                    <NA>
# 180                  NaN                    <NA>
# 181                  NaN                    <NA>
#
# 0    ercp_date_minus_admission_date  ecrp_gte_3_days_naT  ercp_date_na  \
# 1                           13 days                 True         False
# 2                            0 days                False         False
# 3                            2 days                False         False
# 4                            2 days                False         False
# 5                            1 days                False         False
# ..                              ...                  ...           ...
# 177                             NaT                False          True
# 178                             NaT                False          True
# 179                             NaT                False          True
# 180                             NaT                False          True
# 181                             NaT                False          True
#
# 0    ecrp_gte_3_days
# 1               True
# 2              False
# 3              False
# 4              False
# 5              False
# ..               ...
# 177             True
# 178             True
# 179             True
# 180             True
# 181             True
#
# [348 rows x 155 columns]

# %% [markdown]
# ### Write data to csv for external analysis

# %%
input_data_tab1 = input_data.copy()
input_data_tab1.loc[:, 'has_idc'] = input_data_tab1['has_idc'].astype('category')
input_data_tab1.to_csv("data/input_data_tab1.csv", index=False)

# %% [markdown]
# ## Prepare data for TFDF: BASELINE

# %% [markdown]
# ### Features

# %%
TARGET_COLUMN_NAME = ["has_idc"]

ECRP_GTE_3_DAYS = ["ecrp_gte_3_days"]

DATA_HEADER = input_data.columns

CATEGORICAL_FEATURE_NAMES = [
                            'baseline_characteristics_sex', 
                            'baseline_characteristics_nicotine_use',
                            'baseline_characteristics_alcohol_use',
                            ]

NUMERIC_BASELINE_FEATURE_NAMES = [
                            'baseline_characteristics_age',
                            'baseline_characteristics_height_in_cm',
                            'baseline_characteristics_weight_in_kg',
                            #'baseline_characteristics_bmi',
                             'eus_ercp_mrcp_or_as_dhc_width_in_mm'
                            ]

# NUMERIC_LAB_FEATURE_NAMES_ADMISSION = input_data.filter(like='lab_values_admission').columns.tolist()
# Remove variables with mostly missing values
NUMERIC_LAB_FEATURE_NAMES_ADMISSION =['lab_values_admission_crp_in_mg_dl',
                                    #'lab_values_admission_pct_in_ng_ml',
                                    #'lab_values_admission_il6_in_pg_ml',
                                    'lab_values_admission_leukocytes_in_g_l',
                                    'lab_values_admission_bilirubin_in_mg_dl',
                                    'lab_values_admission_got_ast_in_u_l',
                                    'lab_values_admission_gpt_alt_in_u_l',
                                    'lab_values_admission_gamma-gt_in_u_l',
                                    'lab_values_admission_alkaline_phosphatase_in_u_l',
                                    'lab_values_admission_lipase_in_u_l',
                                    'lab_values_admission_inr',
                                    # 'lab_values_admission_quick _in_%',
                                    'lab_values_admission_calcium_in_mmol_l',
                                    # 'lab_values_admission_calcium_alb.-corrected_mmol_l',
                                    'lab_values_admission_triglycerides_in_mg_dl',
                                    'lab_values_admission_hematocrit',
                                    'lab_values_admission_gfr_in_ml_min',
                                    'lab_values_admission_creatinine_in_mg_dl',
                                    'lab_values_admission_urea_in_mg_dl',
                                    #'lab_values_admission_igg4_in_g_l'
                                    ]
# Fix names for use in model

# NUMERIC_LAB_FEATURE_NAMES_DAY3 = input_data.filter(like='lab_values_day_3').columns.tolist()

NUMERIC_LAB_FEATURE_NAMES_DAY3 = ['lab_values_day_3_crp_in_mg_dl',
                                #'lab_values_day_3_pct_in_ng_ml',
                                #'lab_values_day_3_il6_in_pg_ml',
                                'lab_values_day_3_leukocytes_in_g_l',
                                'lab_values_day_3_bilirubin_in_mg_dl',
                                'lab_values_day_3_got_ast_in_u_l',
                                'lab_values_day_3_gpt_alt_in_u_l',
                                'lab_values_day_3_gamma-gt_in_u_l',
                                'lab_values_day_3_alkaline_phosphatase_in_u_l',
                                'lab_values_day_3_lipase_in_u_l',
                                'lab_values_day_3_inr',
                                #'lab_values_day_3_quick _in_%',
                                'lab_values_day_3_calcium_in_mmol_l',
                                #'lab_values_day_3_calcium_alb.-corrected_mmol_l',
                                'lab_values_day_3_triglycerides_in_mg_dl',
                                'lab_values_day_3_hematocrit',
                                'lab_values_day_3_gfr_in_ml_min',
                                'lab_values_day_3_creatinine_in_mg_dl',
                                'lab_values_day_3_urea_in_mg_dl'
                                ]

NUMERIC_FEATURE_NAMES_ALL = NUMERIC_BASELINE_FEATURE_NAMES + NUMERIC_LAB_FEATURE_NAMES_ADMISSION + NUMERIC_LAB_FEATURE_NAMES_DAY3
ALL_FEATURE_NAMES_ADMISSION = TARGET_COLUMN_NAME + CATEGORICAL_FEATURE_NAMES + NUMERIC_BASELINE_FEATURE_NAMES + NUMERIC_LAB_FEATURE_NAMES_ADMISSION
ALL_FEATURE_NAMES_DAY3 = TARGET_COLUMN_NAME + CATEGORICAL_FEATURE_NAMES + NUMERIC_BASELINE_FEATURE_NAMES + NUMERIC_LAB_FEATURE_NAMES_DAY3

# %% [markdown]
# ### Select and convert data types

# %%
x_data = pd.DataFrame()

x_data_pre = input_data.copy()

x_data[TARGET_COLUMN_NAME] = x_data_pre[TARGET_COLUMN_NAME].astype('int')

x_data[CATEGORICAL_FEATURE_NAMES] = x_data_pre[CATEGORICAL_FEATURE_NAMES].fillna('').astype('category')
if len(CATEGORICAL_FEATURE_NAMES) > 0:
    x_data[CATEGORICAL_FEATURE_NAMES] = x_data[CATEGORICAL_FEATURE_NAMES].apply(lambda x: x.cat.codes).astype('int64')

x_data[NUMERIC_FEATURE_NAMES_ALL]= x_data_pre[NUMERIC_FEATURE_NAMES_ALL].fillna(float(np.nan)).astype('float64')

x_data[ECRP_GTE_3_DAYS] = x_data_pre[ECRP_GTE_3_DAYS].astype('bool')

x_data['dhc_in_mm'] = x_data_pre['eus_ercp_mrcp_or_as_dhc_width_in_mm']
x_data['clinical_data_stone_microlithiasis_sludge'] = x_data_pre['clinical_data_stone_microlithiasis_sludge']

x_data.dtypes
# Out:
# has_idc                                               int64
# baseline_characteristics_sex                          int64
# baseline_characteristics_nicotine_use                 int64
# baseline_characteristics_alcohol_use                  int64
# baseline_characteristics_age                        float64
# baseline_characteristics_height_in_cm               float64
# baseline_characteristics_weight_in_kg               float64
# eus_ercp_mrcp_or_as_dhc_width_in_mm                 float64
# lab_values_admission_crp_in_mg_dl                   float64
# lab_values_admission_leukocytes_in_g_l              float64
# lab_values_admission_bilirubin_in_mg_dl             float64
# lab_values_admission_got_ast_in_u_l                 float64
# lab_values_admission_gpt_alt_in_u_l                 float64
# lab_values_admission_gamma-gt_in_u_l                float64
# lab_values_admission_alkaline_phosphatase_in_u_l    float64
# lab_values_admission_lipase_in_u_l                  float64
# lab_values_admission_inr                            float64
# lab_values_admission_calcium_in_mmol_l              float64
# lab_values_admission_triglycerides_in_mg_dl         float64
# lab_values_admission_hematocrit                     float64
# lab_values_admission_gfr_in_ml_min                  float64
# lab_values_admission_creatinine_in_mg_dl            float64
# lab_values_admission_urea_in_mg_dl                  float64
# lab_values_day_3_crp_in_mg_dl                       float64
# lab_values_day_3_leukocytes_in_g_l                  float64
# lab_values_day_3_bilirubin_in_mg_dl                 float64
# lab_values_day_3_got_ast_in_u_l                     float64
# lab_values_day_3_gpt_alt_in_u_l                     float64
# lab_values_day_3_gamma-gt_in_u_l                    float64
# lab_values_day_3_alkaline_phosphatase_in_u_l        float64
# lab_values_day_3_lipase_in_u_l                      float64
# lab_values_day_3_inr                                float64
# lab_values_day_3_calcium_in_mmol_l                  float64
# lab_values_day_3_triglycerides_in_mg_dl             float64
# lab_values_day_3_hematocrit                         float64
# lab_values_day_3_gfr_in_ml_min                      float64
# lab_values_day_3_creatinine_in_mg_dl                float64
# lab_values_day_3_urea_in_mg_dl                      float64
# ecrp_gte_3_days                                        bool
# dhc_in_mm                                           Float64
# clinical_data_stone_microlithiasis_sludge             Int64
# dtype: object

# %% [markdown]
# ### Split data in training and test data

# %%
is_stone = x_data['clinical_data_stone_microlithiasis_sludge'].isin([1, 4, 5, 7])
has_idc = x_data['has_idc'].isin([1])
# Define minority class

no_stones = (is_stone.values == False) | (has_idc.values == False)


x_data = x_data.loc[no_stones]

train_df, test_df = train_test_split(x_data, test_size=0.2, random_state=42)

test_df_ecrp_gte_3_days = test_df[ECRP_GTE_3_DAYS]

test_df_pandas = test_df.copy()

# remove pass_dhc_col from test_df
test_df = test_df.drop(columns=['dhc_in_mm'])
train_df = train_df.drop(columns=['dhc_in_mm'])
test_df = test_df.drop(columns=['clinical_data_stone_microlithiasis_sludge'])

test_df_copy = test_df.copy()


test_labels = test_df_copy[TARGET_COLUMN_NAME].values
test_df_d3 = test_df_copy[ALL_FEATURE_NAMES_DAY3]
test_df_d3.columns = test_df_d3.columns.str.replace('baseline_characteristics_', '')
test_df_d3.columns = test_df_d3.columns.str.replace('lab_values_day_3_', '')
model_cols = test_df_d3.columns
test_df_d32 = test_df_d3.copy()

# %% [markdown]
# ### Write model columns to csv

# %%
model_cols_df = pd.DataFrame()
model_cols_df['model_cols'] = model_cols
model_cols_df['dtypes'] = test_df_d32.dtypes.astype('str').tolist()

# Write to csv
model_cols_df.to_csv("data/model_cols_df.csv", index=False)

# %% [markdown]
# #### Make train tf-dataset

# %%
train_df
# Out:
#      has_idc  baseline_characteristics_sex  \
# 96         1                             1
# 71         0                             1
# 12         0                             0
# 139        1                             0
# 146        0                             0
# ..       ...                           ...
# 34         0                             0
# 38         1                             0
# 20         0                             0
# 107        0                             0
# 30         0                             0
#
#      baseline_characteristics_nicotine_use  \
# 96                                       1
# 71                                       0
# 12                                       0
# 139                                      3
# 146                                      3
# ..                                     ...
# 34                                       0
# 38                                       3
# 20                                       0
# 107                                      3
# 30                                       0
#
#      baseline_characteristics_alcohol_use  baseline_characteristics_age  \
# 96                                      1                          57.0
# 71                                      1                          43.0
# 12                                      1                          77.0
# 139                                     1                          80.0
# 146                                     1                          65.0
# ..                                    ...                           ...
# 34                                      0                          56.0
# 38                                      0                          48.0
# 20                                      0                          50.0
# 107                                     1                          62.0
# 30                                      0                          68.0
#
#      baseline_characteristics_height_in_cm  \
# 96                                   170.0
# 71                                   170.0
# 12                                   162.0
# 139                                  163.0
# 146                                  160.0
# ..                                     ...
# 34                                   158.0
# 38                                     NaN
# 20                                     NaN
# 107                                  160.0
# 30                                     NaN
#
#      baseline_characteristics_weight_in_kg  \
# 96                                   110.0
# 71                                    98.0
# 12                                    63.0
# 139                                   75.5
# 146                                  105.0
# ..                                     ...
# 34                                    73.0
# 38                                     NaN
# 20                                     NaN
# 107                                   71.0
# 30                                     NaN
#
#      eus_ercp_mrcp_or_as_dhc_width_in_mm  lab_values_admission_crp_in_mg_dl  \
# 96                                   5.0                               1.00
# 71                                   3.0                               0.38
# 12                                   5.0                               0.40
# 139                                  9.0                               4.90
# 146                                  8.0                              14.20
# ..                                   ...                                ...
# 34                                   4.8                               6.10
# 38                                   NaN                               2.10
# 20                                   8.0                               0.60
# 107                                 13.0                               0.50
# 30                                   4.0                               0.50
#
#      lab_values_admission_leukocytes_in_g_l  ...  \
# 96                                     4.79  ...
# 71                                    11.10  ...
# 12                                    15.90  ...
# 139                                    9.66  ...
# 146                                    8.34  ...
# ..                                      ...  ...
# 34                                     9.10  ...
# 38                                     7.82  ...
# 20                                    13.50  ...
# 107                                    6.56  ...
# 30                                     5.70  ...
#
#      lab_values_day_3_lipase_in_u_l  lab_values_day_3_inr  \
# 96                            186.0                   1.6
# 71                            244.0                  84.0
# 12                              NaN                   1.2
# 139                             NaN                   0.9
# 146                           101.0                   0.9
# ..                              ...                   ...
# 34                            475.0                   1.1
# 38                             81.0                   0.9
# 20                            207.0                   1.1
# 107                             NaN                   1.2
# 30                              NaN                   1.0
#
#      lab_values_day_3_calcium_in_mmol_l  \
# 96                                  NaN
# 71                                 2.27
# 12                                 2.08
# 139                                 NaN
# 146                                2.32
# ..                                  ...
# 34                                 2.37
# 38                                 2.14
# 20                                 1.94
# 107                                2.33
# 30                                  NaN
#
#      lab_values_day_3_triglycerides_in_mg_dl  lab_values_day_3_hematocrit  \
# 96                                       NaN                        0.301
# 71                                       NaN                        0.440
# 12                                       NaN                        0.309
# 139                                      NaN                        0.345
# 146                                    192.0                        0.361
# ..                                       ...                          ...
# 34                                      73.0                        0.381
# 38                                       NaN                        0.360
# 20                                       NaN                        0.350
# 107                                      NaN                        0.289
# 30                                       NaN                        0.405
#
#      lab_values_day_3_gfr_in_ml_min  lab_values_day_3_creatinine_in_mg_dl  \
# 96                             93.0                                   1.1
# 71                            105.0                                   0.9
# 12                             74.0                                   1.0
# 139                            90.0                                   0.5
# 146                            48.0                                   1.2
# ..                              ...                                   ...
# 34                             60.0                                   0.7
# 38                             90.0                                   0.8
# 20                            109.0                                   0.8
# 107                           100.0                                   0.6
# 30                             49.0                                   1.2
#
#      lab_values_day_3_urea_in_mg_dl  ecrp_gte_3_days  \
# 96                              NaN             True
# 71                             19.0             True
# 12                              NaN             True
# 139                             NaN             True
# 146                            46.0            False
# ..                              ...              ...
# 34                             10.0             True
# 38                             17.0            False
# 20                              NaN             True
# 107                            13.0             True
# 30                              NaN             True
#
#      clinical_data_stone_microlithiasis_sludge
# 96                                           2
# 71                                           3
# 12                                           1
# 139                                          6
# 146                                          6
# ..                                         ...
# 34                                           1
# 38                                           3
# 20                                           1
# 107                                          4
# 30                                           1
#
# [203 rows x 40 columns]

# %%
train_df = train_df[ALL_FEATURE_NAMES_ADMISSION + ["clinical_data_stone_microlithiasis_sludge"]]
train_df.columns = train_df.columns.str.replace('baseline_characteristics_', '')
train_df.columns = train_df.columns.str.replace('lab_values_admission_', '')

train_df.dtypes
# Out:
# has_idc                                        int64
# sex                                            int64
# nicotine_use                                   int64
# alcohol_use                                    int64
# age                                          float64
# height_in_cm                                 float64
# weight_in_kg                                 float64
# eus_ercp_mrcp_or_as_dhc_width_in_mm          float64
# crp_in_mg_dl                                 float64
# leukocytes_in_g_l                            float64
# bilirubin_in_mg_dl                           float64
# got_ast_in_u_l                               float64
# gpt_alt_in_u_l                               float64
# gamma-gt_in_u_l                              float64
# alkaline_phosphatase_in_u_l                  float64
# lipase_in_u_l                                float64
# inr                                          float64
# calcium_in_mmol_l                            float64
# triglycerides_in_mg_dl                       float64
# hematocrit                                   float64
# gfr_in_ml_min                                float64
# creatinine_in_mg_dl                          float64
# urea_in_mg_dl                                float64
# clinical_data_stone_microlithiasis_sludge      Int64
# dtype: object

# %%
select_cols = model_cols 
select_cols = select_cols.append(pd.Index(["clinical_data_stone_microlithiasis_sludge"]))

train_df = train_df[select_cols]

# %% [markdown]
# ### Impute missing values
# Uses the MICE algorithm.

# %%
# Impute training data
imputer = IterativeImputer(random_state=41)
imputed = imputer.fit_transform(train_df)
df_imputed = pd.DataFrame(imputed, columns=train_df.columns)

df_imputed['has_idc'] = df_imputed['has_idc'].astype('int64')

train_df_pd = df_imputed.copy()
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.

# %% [markdown]
# ### Oversample minority classes (sludge and microlithiasis)

# %%
# Define minortiy class


is_stone = df_imputed['clinical_data_stone_microlithiasis_sludge'].isin([1, 4, 5, 7])
has_idc = df_imputed['has_idc'].isin([1])
# Define minority class

no_stones = (is_stone.values == False) | (has_idc.values == False)


df_imputed = df_imputed.loc[no_stones]

# %%
is_sl_or_mic = df_imputed['clinical_data_stone_microlithiasis_sludge'].isin([2, 3, 6])
is_sl_or_mic = is_sl_or_mic.astype('int64')

# %%
from imblearn.over_sampling import SMOTE
# Oversample the minority class using the SMOTE algorithm

# Apply SMOTE oversampling
smote = SMOTE(random_state=42, sampling_strategy='minority')
train_df_oversampled, y_train_oversampled = smote.fit_resample(df_imputed, is_sl_or_mic)

print("Before oversampling" + str(df_imputed.shape) + "; after oversampling:" + str(train_df_oversampled.shape))
# Out:
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# /opt/conda/lib/python3.11/site-packages/sklearn/utils/validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
# Before oversampling(203, 24); after oversampling:(244, 24)

# %% [markdown]
# ### Convert to tf dataset

# %%
train_df = train_df_oversampled[model_cols]
train_df["sex"] = train_df["sex"].astype('int64')
train_df["nicotine_use"] = train_df["nicotine_use"].astype('int64')

train_cols = train_df.dtypes
train_df = tfdf.keras.pd_dataframe_to_tf_dataset(train_df, label="has_idc")
# Out:
# /tmp/ipykernel_34671/770190344.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /tmp/ipykernel_34671/770190344.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# #### Make test tf-dataset

# %%
test_labels = test_df[TARGET_COLUMN_NAME].values
test_df = test_df[ALL_FEATURE_NAMES_ADMISSION]
test_df.columns = test_df.columns.str.replace('baseline_characteristics_', '')
test_df.columns = test_df.columns.str.replace('lab_values_admission_', '')
test_df = test_df[model_cols]
test_cols = test_df.dtypes
test_df = tfdf.keras.pd_dataframe_to_tf_dataset(test_df, label="has_idc")

# %%
train_cols == test_cols
# Out:
# has_idc                                 True
# sex                                     True
# nicotine_use                            True
# alcohol_use                            False
# age                                     True
# height_in_cm                            True
# weight_in_kg                            True
# eus_ercp_mrcp_or_as_dhc_width_in_mm     True
# crp_in_mg_dl                            True
# leukocytes_in_g_l                       True
# bilirubin_in_mg_dl                      True
# got_ast_in_u_l                          True
# gpt_alt_in_u_l                          True
# gamma-gt_in_u_l                         True
# alkaline_phosphatase_in_u_l             True
# lipase_in_u_l                           True
# inr                                     True
# calcium_in_mmol_l                       True
# triglycerides_in_mg_dl                  True
# hematocrit                              True
# gfr_in_ml_min                           True
# creatinine_in_mg_dl                     True
# urea_in_mg_dl                           True
# dtype: bool

# %%
test_cols
# Out:
# has_idc                                  int64
# sex                                      int64
# nicotine_use                             int64
# alcohol_use                              int64
# age                                    float64
# height_in_cm                           float64
# weight_in_kg                           float64
# eus_ercp_mrcp_or_as_dhc_width_in_mm    float64
# crp_in_mg_dl                           float64
# leukocytes_in_g_l                      float64
# bilirubin_in_mg_dl                     float64
# got_ast_in_u_l                         float64
# gpt_alt_in_u_l                         float64
# gamma-gt_in_u_l                        float64
# alkaline_phosphatase_in_u_l            float64
# lipase_in_u_l                          float64
# inr                                    float64
# calcium_in_mmol_l                      float64
# triglycerides_in_mg_dl                 float64
# hematocrit                             float64
# gfr_in_ml_min                          float64
# creatinine_in_mg_dl                    float64
# urea_in_mg_dl                          float64
# dtype: object

# %% [markdown]
# ## Train the model - random forests BASELINE

# %%
# Crete a tuner for model optimization on sensitivity (i.e. has_idc=1)

# model_rf = tfdf.keras.GradientBoostedTreesModel()
model_rf = tfdf.keras.RandomForestModel(
    #tuner=tuner,
    compute_oob_variable_importances=True,
    )
model_rf.fit(train_df)
# Out:
# Use /tmp/tmpvhuvsr5u as temporary training directory
# Reading training dataset...
# Training dataset read in 0:00:03.231276. Found 244 examples.
# Training model...
# Model trained in 0:00:00.074883
# Compiling model...
# [INFO 23-12-18 16:53:19.8265 UTC kernel.cc:1233] Loading model from path /tmp/tmpvhuvsr5u/model/ with prefix d81b8bcd84394657
# [INFO 23-12-18 16:53:19.8369 UTC decision_forest.cc:660] Model loaded with 300 root(s), 11766 node(s), and 22 input feature(s).
# [INFO 23-12-18 16:53:19.8369 UTC abstract_model.cc:1344] Engine "RandomForestOptPred" built
# [INFO 23-12-18 16:53:19.8369 UTC kernel.cc:1061] Use fast generic engine
# Model compiled.

# %% [markdown]
# ### Evaluate the model
# We adjust the threshold to 0.25 for sensitivity.

# %%
model_rf.compile(metrics=["accuracy", "AUC", "TruePositives", "TrueNegatives", "FalsePositives", "FalseNegatives"])

# %%
probs = model_rf.predict(test_df)
preds = probs > 0.25

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
confusion_matrix(test_labels, preds)

import matplotlib.pyplot as plt

cm = confusion_matrix(test_labels, preds)

disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# Out:
# 1/1 [==============================] - 0s 36ms/step

# %% [markdown]
# **Figure.** Confusion matrix for the test set: True positives (TP), true negatives (TN), false positives (FP), false negatives (FN).

# %%
# Write data for analysis in R to csv
test_df_pandas['pred_prob'] = probs
test_df_pandas['pred_idc'] = preds
test_df_pandas.to_csv("data/test_df_pandas.csv", index=False)

# %%
evaluation = model_rf.evaluate(test_df, return_dict=True)
for name, value in evaluation.items():
  print(f"{name}: {value:.4f}")
# Out:
# 1/1 [==============================] - 0s 496ms/step - loss: 0.0000e+00 - accuracy: 0.7255 - auc: 0.7880 - true_positives: 4.0000 - true_negatives: 33.0000 - false_positives: 3.0000 - false_negatives: 11.0000
# loss: 0.0000
# accuracy: 0.7255
# auc: 0.7880
# true_positives: 4.0000
# true_negatives: 33.0000
# false_positives: 3.0000
# false_negatives: 11.0000

# %% [markdown]
# #### Inspect the model

# %%
print(model_rf.summary())
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (22):
# 	age
# 	alcohol_use
# 	alkaline_phosphatase_in_u_l
# 	bilirubin_in_mg_dl
# 	calcium_in_mmol_l
# 	creatinine_in_mg_dl
# 	crp_in_mg_dl
# 	eus_ercp_mrcp_or_as_dhc_width_in_mm
# 	gamma-gt_in_u_l
# 	gfr_in_ml_min
# 	got_ast_in_u_l
# 	gpt_alt_in_u_l
# 	height_in_cm
# 	hematocrit
# 	inr
# 	leukocytes_in_g_l
# 	lipase_in_u_l
# 	nicotine_use
# 	sex
# 	triglycerides_in_mg_dl
# 	urea_in_mg_dl
# 	weight_in_kg
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.288314 ################
#     2.                   "calcium_in_mmol_l"  0.208632 ######
#     3.                                 "age"  0.204478 #####
#     4.                        "height_in_cm"  0.202849 #####
#     5.                        "crp_in_mg_dl"  0.184645 ###
#     6.         "alkaline_phosphatase_in_u_l"  0.183776 ###
#     7.                          "hematocrit"  0.182414 ###
#     8.                        "weight_in_kg"  0.177899 ##
#     9.                      "got_ast_in_u_l"  0.177872 ##
#    10.                                 "inr"  0.176273 ##
#    11.                     "gamma-gt_in_u_l"  0.175753 ##
#    12.              "triglycerides_in_mg_dl"  0.174830 ##
#    13.                       "lipase_in_u_l"  0.174738 ##
#    14.                   "leukocytes_in_g_l"  0.174604 ##
#    15.                  "bilirubin_in_mg_dl"  0.170217 #
#    16.                       "gfr_in_ml_min"  0.169959 #
#    17.                      "gpt_alt_in_u_l"  0.169505 #
#    18.                       "urea_in_mg_dl"  0.169468 #
#    19.                 "creatinine_in_mg_dl"  0.169225 #
#    20.                         "alcohol_use"  0.159678
#    21.                        "nicotine_use"  0.159419
#    22.                                 "sex"  0.157824
#
# Variable Importance: MEAN_DECREASE_IN_ACCURACY:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.016393 ################
#     2.                   "calcium_in_mmol_l"  0.008197 ###########
#     3.                  "bilirubin_in_mg_dl"  0.004098 #########
#     4.                                 "inr"  0.004098 #########
#     5.                      "gpt_alt_in_u_l"  0.004098 #########
#     6.                         "alcohol_use"  0.000000 ######
#     7.                       "urea_in_mg_dl"  0.000000 ######
#     8.                                 "sex"  0.000000 ######
#     9.                       "lipase_in_u_l"  0.000000 ######
#    10.                   "leukocytes_in_g_l"  0.000000 ######
#    11.                     "gamma-gt_in_u_l"  0.000000 ######
#    12.                        "crp_in_mg_dl"  0.000000 ######
#    13.                                 "age"  0.000000 ######
#    14.                        "height_in_cm" -0.004098 ####
#    15.                          "hematocrit" -0.004098 ####
#    16.                        "nicotine_use" -0.004098 ####
#    17.         "alkaline_phosphatase_in_u_l" -0.004098 ####
#    18.              "triglycerides_in_mg_dl" -0.004098 ####
#    19.                      "got_ast_in_u_l" -0.008197 ##
#    20.                       "gfr_in_ml_min" -0.008197 ##
#    21.                        "weight_in_kg" -0.008197 ##
#    22.                 "creatinine_in_mg_dl" -0.012295
#
# Variable Importance: MEAN_DECREASE_IN_AP_2_VS_OTHERS:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.217492 ################
#     2.                                 "age"  0.055736 ####
#     3.                          "hematocrit"  0.017361 #
#     4.                       "lipase_in_u_l"  0.017107 #
#     5.                        "crp_in_mg_dl"  0.015633 #
#     6.                     "gamma-gt_in_u_l"  0.011120 #
#     7.                                 "inr"  0.008071 #
#     8.                         "alcohol_use"  0.006856 #
#     9.              "triglycerides_in_mg_dl"  0.006344 #
#    10.                  "bilirubin_in_mg_dl"  0.006024 #
#    11.                   "leukocytes_in_g_l"  0.005377 #
#    12.                                 "sex"  0.002946
#    13.                   "calcium_in_mmol_l"  0.002266
#    14.                 "creatinine_in_mg_dl"  0.001645
#    15.                      "gpt_alt_in_u_l"  0.000524
#    16.                        "height_in_cm"  0.000021
#    17.                       "gfr_in_ml_min" -0.000753
#    18.                        "weight_in_kg" -0.001226
#    19.                        "nicotine_use" -0.001455
#    20.                       "urea_in_mg_dl" -0.002223
#    21.                      "got_ast_in_u_l" -0.003639
#    22.         "alkaline_phosphatase_in_u_l" -0.008802
#
# Variable Importance: MEAN_DECREASE_IN_AUC_2_VS_OTHERS:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.143585 ################
#     2.                        "crp_in_mg_dl"  0.022386 ##
#     3.                                 "inr"  0.011123 #
#     4.                   "calcium_in_mmol_l"  0.009872 #
#     5.                          "hematocrit"  0.009501 #
#     6.                                 "age"  0.006999 #
#     7.                  "bilirubin_in_mg_dl"  0.006118 #
#     8.                        "height_in_cm"  0.005515 #
#     9.                   "leukocytes_in_g_l"  0.003940 #
#    10.                        "weight_in_kg"  0.003893
#    11.                      "got_ast_in_u_l"  0.003708
#    12.                         "alcohol_use"  0.003615
#    13.                       "gfr_in_ml_min"  0.003291
#    14.                 "creatinine_in_mg_dl"  0.003059
#    15.              "triglycerides_in_mg_dl"  0.002225
#    16.                       "urea_in_mg_dl"  0.001298
#    17.                                 "sex"  0.000649
#    18.                       "lipase_in_u_l"  0.000185
#    19.                      "gpt_alt_in_u_l" -0.001437
#    20.                     "gamma-gt_in_u_l" -0.001947
#    21.                        "nicotine_use" -0.002827
#    22.         "alkaline_phosphatase_in_u_l" -0.005376
#
# Variable Importance: MEAN_DECREASE_IN_PRAUC_2_VS_OTHERS:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.218489 ################
#     2.                                 "age"  0.056089 ####
#     3.                          "hematocrit"  0.017225 #
#     4.                        "crp_in_mg_dl"  0.015496 #
#     5.                       "lipase_in_u_l"  0.013584 #
#     6.                     "gamma-gt_in_u_l"  0.009612 #
#     7.                                 "inr"  0.006507 #
#     8.                   "calcium_in_mmol_l"  0.006365 #
#     9.                         "alcohol_use"  0.006219 #
#    10.              "triglycerides_in_mg_dl"  0.005570 #
#    11.                  "bilirubin_in_mg_dl"  0.004726
#    12.                   "leukocytes_in_g_l"  0.004131
#    13.                                 "sex"  0.002771
#    14.                 "creatinine_in_mg_dl"  0.000484
#    15.                      "gpt_alt_in_u_l" -0.000644
#    16.                        "height_in_cm" -0.000672
#    17.                       "gfr_in_ml_min" -0.001086
#    18.                        "weight_in_kg" -0.001502
#    19.                        "nicotine_use" -0.001826
#    20.                       "urea_in_mg_dl" -0.003702
#    21.                      "got_ast_in_u_l" -0.004754
#    22.         "alkaline_phosphatase_in_u_l" -0.009021
#
# Variable Importance: NUM_AS_ROOT:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm" 79.000000 ################
#     2.                                 "age" 38.000000 #######
#     3.                   "calcium_in_mmol_l" 36.000000 #######
#     4.                        "height_in_cm" 35.000000 ######
#     5.                        "crp_in_mg_dl" 18.000000 ###
#     6.         "alkaline_phosphatase_in_u_l" 15.000000 ##
#     7.                     "gamma-gt_in_u_l" 14.000000 ##
#     8.                          "hematocrit" 13.000000 ##
#     9.                        "weight_in_kg" 12.000000 ##
#    10.                                 "inr" 10.000000 #
#    11.                      "got_ast_in_u_l"  8.000000 #
#    12.              "triglycerides_in_mg_dl"  7.000000 #
#    13.                  "bilirubin_in_mg_dl"  4.000000
#    14.                 "creatinine_in_mg_dl"  3.000000
#    15.                   "leukocytes_in_g_l"  3.000000
#    16.                       "gfr_in_ml_min"  2.000000
#    17.                      "gpt_alt_in_u_l"  2.000000
#    18.                       "lipase_in_u_l"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm" 556.000000 ################
#     2.                   "calcium_in_mmol_l" 408.000000 ###########
#     3.                                 "age" 369.000000 ##########
#     4.                        "height_in_cm" 330.000000 #########
#     5.                          "hematocrit" 317.000000 ########
#     6.                       "lipase_in_u_l" 310.000000 ########
#     7.                        "crp_in_mg_dl" 302.000000 ########
#     8.         "alkaline_phosphatase_in_u_l" 298.000000 ########
#     9.                   "leukocytes_in_g_l" 296.000000 ########
#    10.                        "weight_in_kg" 296.000000 ########
#    11.                      "got_ast_in_u_l" 295.000000 ########
#    12.              "triglycerides_in_mg_dl" 268.000000 #######
#    13.                       "urea_in_mg_dl" 261.000000 #######
#    14.                  "bilirubin_in_mg_dl" 238.000000 ######
#    15.                      "gpt_alt_in_u_l" 238.000000 ######
#    16.                     "gamma-gt_in_u_l" 233.000000 ######
#    17.                       "gfr_in_ml_min" 202.000000 #####
#    18.                                 "inr" 200.000000 #####
#    19.                 "creatinine_in_mg_dl" 166.000000 ####
#    20.                         "alcohol_use" 65.000000 #
#    21.                        "nicotine_use" 59.000000
#    22.                                 "sex" 26.000000
#
# Variable Importance: SUM_SCORE:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm" 5901.566754 ################
#     2.                   "calcium_in_mmol_l" 2343.652594 ######
#     3.                                 "age" 2060.503928 #####
#     4.                        "height_in_cm" 1839.967955 ####
#     5.                          "hematocrit" 1549.157974 ####
#     6.                        "crp_in_mg_dl" 1547.824468 ####
#     7.                       "lipase_in_u_l" 1474.532189 ###
#     8.                      "got_ast_in_u_l" 1369.363230 ###
#     9.                        "weight_in_kg" 1363.778723 ###
#    10.         "alkaline_phosphatase_in_u_l" 1351.465344 ###
#    11.                   "leukocytes_in_g_l" 1290.433637 ###
#    12.              "triglycerides_in_mg_dl" 1231.713634 ###
#    13.                       "urea_in_mg_dl" 1174.474990 ###
#    14.                  "bilirubin_in_mg_dl" 1070.378753 ##
#    15.                     "gamma-gt_in_u_l" 1008.661370 ##
#    16.                      "gpt_alt_in_u_l" 1001.332846 ##
#    17.                                 "inr" 901.021298 ##
#    18.                       "gfr_in_ml_min" 866.718827 ##
#    19.                 "creatinine_in_mg_dl" 715.439580 #
#    20.                         "alcohol_use" 281.044473
#    21.                        "nicotine_use" 241.191353
#    22.                                 "sex" 79.772901
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.77459 logloss:0.455304
# Number of trees: 300
# Total number of nodes: 11766
#
# Number of nodes by tree:
# Count: 300 Average: 39.22 StdDev: 4.1527
# Min: 29 Max: 53 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  4   1.33%   1.33% #
# [ 30, 31)  0   0.00%   1.33%
# [ 31, 32) 11   3.67%   5.00% ##
# [ 32, 34) 19   6.33%  11.33% ###
# [ 34, 35)  0   0.00%  11.33%
# [ 35, 36) 27   9.00%  20.33% ####
# [ 36, 37)  0   0.00%  20.33%
# [ 37, 39) 45  15.00%  35.33% #######
# [ 39, 40) 67  22.33%  57.67% ##########
# [ 40, 41)  0   0.00%  57.67%
# [ 41, 42) 58  19.33%  77.00% #########
# [ 42, 44) 37  12.33%  89.33% ######
# [ 44, 45)  0   0.00%  89.33%
# [ 45, 46) 17   5.67%  95.00% ###
# [ 46, 47)  0   0.00%  95.00%
# [ 47, 49)  8   2.67%  97.67% #
# [ 49, 50)  5   1.67%  99.33% #
# [ 50, 51)  0   0.00%  99.33%
# [ 51, 52)  1   0.33%  99.67%
# [ 52, 53]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 6033 Average: 5.40046 StdDev: 1.90859
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)   56   0.93%   0.93%
# [  2,  3)  214   3.55%   4.48% ##
# [  3,  4)  679  11.25%  15.73% #####
# [  4,  5) 1086  18.00%  33.73% #########
# [  5,  6) 1266  20.98%  54.72% ##########
# [  6,  7) 1137  18.85%  73.56% #########
# [  7,  8)  798  13.23%  86.79% ######
# [  8,  9)  414   6.86%  93.65% ###
# [  9, 10)  230   3.81%  97.46% ##
# [ 10, 11)  102   1.69%  99.15% #
# [ 11, 12)   38   0.63%  99.78%
# [ 12, 13)   11   0.18%  99.97%
# [ 13, 13]    2   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 6033 Average: 12.1333 StdDev: 13.5725
# Min: 5 Max: 118 Ignored: 0
# ----------------------------------------------
# [   5,  10) 4239  70.26%  70.26% ##########
# [  10,  16)  711  11.79%  82.05% ##
# [  16,  22)  331   5.49%  87.54% #
# [  22,  27)  161   2.67%  90.20%
# [  27,  33)  137   2.27%  92.47%
# [  33,  39)  101   1.67%  94.15%
# [  39,  44)   70   1.16%  95.31%
# [  44,  50)   65   1.08%  96.39%
# [  50,  56)   46   0.76%  97.15%
# [  56,  62)   48   0.80%  97.94%
# [  62,  67)   32   0.53%  98.48%
# [  67,  73)   29   0.48%  98.96%
# [  73,  79)   25   0.41%  99.37%
# [  79,  84)    9   0.15%  99.52%
# [  84,  90)   15   0.25%  99.77%
# [  90,  96)    5   0.08%  99.85%
# [  96, 101)    4   0.07%  99.92%
# [ 101, 107)    2   0.03%  99.95%
# [ 107, 113)    1   0.02%  99.97%
# [ 113, 118]    2   0.03% 100.00%
#
# Attribute in nodes:
# 	556 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	408 : calcium_in_mmol_l [NUMERICAL]
# 	369 : age [NUMERICAL]
# 	330 : height_in_cm [NUMERICAL]
# 	317 : hematocrit [NUMERICAL]
# 	310 : lipase_in_u_l [NUMERICAL]
# 	302 : crp_in_mg_dl [NUMERICAL]
# 	298 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	296 : weight_in_kg [NUMERICAL]
# 	296 : leukocytes_in_g_l [NUMERICAL]
# 	295 : got_ast_in_u_l [NUMERICAL]
# 	268 : triglycerides_in_mg_dl [NUMERICAL]
# 	261 : urea_in_mg_dl [NUMERICAL]
# 	238 : gpt_alt_in_u_l [NUMERICAL]
# 	238 : bilirubin_in_mg_dl [NUMERICAL]
# 	233 : gamma-gt_in_u_l [NUMERICAL]
# 	202 : gfr_in_ml_min [NUMERICAL]
# 	200 : inr [NUMERICAL]
# 	166 : creatinine_in_mg_dl [NUMERICAL]
# 	65 : alcohol_use [NUMERICAL]
# 	59 : nicotine_use [NUMERICAL]
# 	26 : sex [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	79 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	38 : age [NUMERICAL]
# 	36 : calcium_in_mmol_l [NUMERICAL]
# 	35 : height_in_cm [NUMERICAL]
# 	18 : crp_in_mg_dl [NUMERICAL]
# 	15 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	14 : gamma-gt_in_u_l [NUMERICAL]
# 	13 : hematocrit [NUMERICAL]
# 	12 : weight_in_kg [NUMERICAL]
# 	10 : inr [NUMERICAL]
# 	8 : got_ast_in_u_l [NUMERICAL]
# 	7 : triglycerides_in_mg_dl [NUMERICAL]
# 	4 : bilirubin_in_mg_dl [NUMERICAL]
# 	3 : leukocytes_in_g_l [NUMERICAL]
# 	3 : creatinine_in_mg_dl [NUMERICAL]
# 	2 : gpt_alt_in_u_l [NUMERICAL]
# 	2 : gfr_in_ml_min [NUMERICAL]
# 	1 : lipase_in_u_l [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	172 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	84 : calcium_in_mmol_l [NUMERICAL]
# 	78 : age [NUMERICAL]
# 	76 : height_in_cm [NUMERICAL]
# 	48 : crp_in_mg_dl [NUMERICAL]
# 	42 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	40 : hematocrit [NUMERICAL]
# 	36 : weight_in_kg [NUMERICAL]
# 	33 : leukocytes_in_g_l [NUMERICAL]
# 	31 : got_ast_in_u_l [NUMERICAL]
# 	29 : inr [NUMERICAL]
# 	29 : gamma-gt_in_u_l [NUMERICAL]
# 	25 : lipase_in_u_l [NUMERICAL]
# 	24 : triglycerides_in_mg_dl [NUMERICAL]
# 	24 : gpt_alt_in_u_l [NUMERICAL]
# 	18 : urea_in_mg_dl [NUMERICAL]
# 	18 : creatinine_in_mg_dl [NUMERICAL]
# 	16 : bilirubin_in_mg_dl [NUMERICAL]
# 	14 : gfr_in_ml_min [NUMERICAL]
# 	3 : nicotine_use [NUMERICAL]
# 	3 : alcohol_use [NUMERICAL]
# 	1 : sex [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	259 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	140 : calcium_in_mmol_l [NUMERICAL]
# 	137 : age [NUMERICAL]
# 	134 : height_in_cm [NUMERICAL]
# 	92 : hematocrit [NUMERICAL]
# 	90 : crp_in_mg_dl [NUMERICAL]
# 	86 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	82 : leukocytes_in_g_l [NUMERICAL]
# 	79 : weight_in_kg [NUMERICAL]
# 	76 : lipase_in_u_l [NUMERICAL]
# 	69 : got_ast_in_u_l [NUMERICAL]
# 	65 : triglycerides_in_mg_dl [NUMERICAL]
# 	59 : gamma-gt_in_u_l [NUMERICAL]
# 	59 : bilirubin_in_mg_dl [NUMERICAL]
# 	58 : inr [NUMERICAL]
# 	58 : gpt_alt_in_u_l [NUMERICAL]
# 	52 : gfr_in_ml_min [NUMERICAL]
# 	50 : urea_in_mg_dl [NUMERICAL]
# 	47 : creatinine_in_mg_dl [NUMERICAL]
# 	12 : nicotine_use [NUMERICAL]
# 	10 : alcohol_use [NUMERICAL]
# 	4 : sex [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	346 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	221 : calcium_in_mmol_l [NUMERICAL]
# 	207 : age [NUMERICAL]
# 	199 : height_in_cm [NUMERICAL]
# 	156 : hematocrit [NUMERICAL]
# 	143 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	142 : leukocytes_in_g_l [NUMERICAL]
# 	138 : crp_in_mg_dl [NUMERICAL]
# 	137 : weight_in_kg [NUMERICAL]
# 	134 : lipase_in_u_l [NUMERICAL]
# 	129 : got_ast_in_u_l [NUMERICAL]
# 	116 : triglycerides_in_mg_dl [NUMERICAL]
# 	105 : bilirubin_in_mg_dl [NUMERICAL]
# 	101 : inr [NUMERICAL]
# 	101 : gamma-gt_in_u_l [NUMERICAL]
# 	100 : gpt_alt_in_u_l [NUMERICAL]
# 	91 : urea_in_mg_dl [NUMERICAL]
# 	84 : gfr_in_ml_min [NUMERICAL]
# 	77 : creatinine_in_mg_dl [NUMERICAL]
# 	25 : alcohol_use [NUMERICAL]
# 	24 : nicotine_use [NUMERICAL]
# 	11 : sex [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	474 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	340 : calcium_in_mmol_l [NUMERICAL]
# 	314 : age [NUMERICAL]
# 	270 : height_in_cm [NUMERICAL]
# 	256 : lipase_in_u_l [NUMERICAL]
# 	256 : hematocrit [NUMERICAL]
# 	252 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	248 : crp_in_mg_dl [NUMERICAL]
# 	242 : got_ast_in_u_l [NUMERICAL]
# 	235 : leukocytes_in_g_l [NUMERICAL]
# 	234 : weight_in_kg [NUMERICAL]
# 	219 : triglycerides_in_mg_dl [NUMERICAL]
# 	201 : urea_in_mg_dl [NUMERICAL]
# 	191 : gpt_alt_in_u_l [NUMERICAL]
# 	189 : bilirubin_in_mg_dl [NUMERICAL]
# 	188 : gamma-gt_in_u_l [NUMERICAL]
# 	161 : inr [NUMERICAL]
# 	160 : gfr_in_ml_min [NUMERICAL]
# 	133 : creatinine_in_mg_dl [NUMERICAL]
# 	50 : alcohol_use [NUMERICAL]
# 	46 : nicotine_use [NUMERICAL]
# 	18 : sex [NUMERICAL]
#
# Condition type in nodes:
# 	5733 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	844 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1718 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2787 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4677 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.767442 logloss:8.38224
# 	trees: 11, Out-of-bag evaluation: accuracy:0.737705 logloss:3.69898
# 	trees: 21, Out-of-bag evaluation: accuracy:0.741803 logloss:3.70446
# 	trees: 31, Out-of-bag evaluation: accuracy:0.770492 logloss:1.99364
# 	trees: 49, Out-of-bag evaluation: accuracy:0.782787 logloss:0.877043
# 	trees: 66, Out-of-bag evaluation: accuracy:0.77459 logloss:0.457708
# 	trees: 78, Out-of-bag evaluation: accuracy:0.795082 logloss:0.467283
# 	trees: 90, Out-of-bag evaluation: accuracy:0.790984 logloss:0.464115
# 	trees: 100, Out-of-bag evaluation: accuracy:0.795082 logloss:0.461738
# 	trees: 110, Out-of-bag evaluation: accuracy:0.795082 logloss:0.462193
# 	trees: 121, Out-of-bag evaluation: accuracy:0.786885 logloss:0.462452
# 	trees: 138, Out-of-bag evaluation: accuracy:0.790984 logloss:0.453307
# 	trees: 153, Out-of-bag evaluation: accuracy:0.786885 logloss:0.456613
# 	trees: 165, Out-of-bag evaluation: accuracy:0.77459 logloss:0.456832
# 	trees: 179, Out-of-bag evaluation: accuracy:0.778689 logloss:0.457374
# 	trees: 189, Out-of-bag evaluation: accuracy:0.766393 logloss:0.459438
# 	trees: 200, Out-of-bag evaluation: accuracy:0.77459 logloss:0.457705
# 	trees: 210, Out-of-bag evaluation: accuracy:0.770492 logloss:0.455157
# 	trees: 220, Out-of-bag evaluation: accuracy:0.770492 logloss:0.455359
# 	trees: 234, Out-of-bag evaluation: accuracy:0.770492 logloss:0.451948
# 	trees: 245, Out-of-bag evaluation: accuracy:0.77459 logloss:0.453358
# 	trees: 255, Out-of-bag evaluation: accuracy:0.770492 logloss:0.455123
# 	trees: 265, Out-of-bag evaluation: accuracy:0.770492 logloss:0.455681
# 	trees: 275, Out-of-bag evaluation: accuracy:0.770492 logloss:0.45562
# 	trees: 285, Out-of-bag evaluation: accuracy:0.770492 logloss:0.454501
# 	trees: 300, Out-of-bag evaluation: accuracy:0.77459 logloss:0.455304
#
# None

# %%
inspector = model_rf.make_inspector()

inspector.evaluation()
# Out:
# Evaluation(num_examples=244, accuracy=0.7745901639344263, loss=0.4553035293537818, rmse=None, ndcg=None, aucs=None, auuc=None, qini=None)

# %%
# Print all the variable importances
model_rf.summary()

# List the available variable importances
print(inspector.variable_importances().keys())

# Show a specific variable importance
# Each line is: (feature name, (index of the feature), importance score)
inspector.variable_importances()["MEAN_DECREASE_IN_ACCURACY"]
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1 (1.00 Byte)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 1 (1.00 Byte)
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (22):
# 	age
# 	alcohol_use
# 	alkaline_phosphatase_in_u_l
# 	bilirubin_in_mg_dl
# 	calcium_in_mmol_l
# 	creatinine_in_mg_dl
# 	crp_in_mg_dl
# 	eus_ercp_mrcp_or_as_dhc_width_in_mm
# 	gamma-gt_in_u_l
# 	gfr_in_ml_min
# 	got_ast_in_u_l
# 	gpt_alt_in_u_l
# 	height_in_cm
# 	hematocrit
# 	inr
# 	leukocytes_in_g_l
# 	lipase_in_u_l
# 	nicotine_use
# 	sex
# 	triglycerides_in_mg_dl
# 	urea_in_mg_dl
# 	weight_in_kg
#
# No weights
#
# Variable Importance: INV_MEAN_MIN_DEPTH:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.288314 ################
#     2.                   "calcium_in_mmol_l"  0.208632 ######
#     3.                                 "age"  0.204478 #####
#     4.                        "height_in_cm"  0.202849 #####
#     5.                        "crp_in_mg_dl"  0.184645 ###
#     6.         "alkaline_phosphatase_in_u_l"  0.183776 ###
#     7.                          "hematocrit"  0.182414 ###
#     8.                        "weight_in_kg"  0.177899 ##
#     9.                      "got_ast_in_u_l"  0.177872 ##
#    10.                                 "inr"  0.176273 ##
#    11.                     "gamma-gt_in_u_l"  0.175753 ##
#    12.              "triglycerides_in_mg_dl"  0.174830 ##
#    13.                       "lipase_in_u_l"  0.174738 ##
#    14.                   "leukocytes_in_g_l"  0.174604 ##
#    15.                  "bilirubin_in_mg_dl"  0.170217 #
#    16.                       "gfr_in_ml_min"  0.169959 #
#    17.                      "gpt_alt_in_u_l"  0.169505 #
#    18.                       "urea_in_mg_dl"  0.169468 #
#    19.                 "creatinine_in_mg_dl"  0.169225 #
#    20.                         "alcohol_use"  0.159678
#    21.                        "nicotine_use"  0.159419
#    22.                                 "sex"  0.157824
#
# Variable Importance: MEAN_DECREASE_IN_ACCURACY:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.016393 ################
#     2.                   "calcium_in_mmol_l"  0.008197 ###########
#     3.                  "bilirubin_in_mg_dl"  0.004098 #########
#     4.                                 "inr"  0.004098 #########
#     5.                      "gpt_alt_in_u_l"  0.004098 #########
#     6.                         "alcohol_use"  0.000000 ######
#     7.                       "urea_in_mg_dl"  0.000000 ######
#     8.                                 "sex"  0.000000 ######
#     9.                       "lipase_in_u_l"  0.000000 ######
#    10.                   "leukocytes_in_g_l"  0.000000 ######
#    11.                     "gamma-gt_in_u_l"  0.000000 ######
#    12.                        "crp_in_mg_dl"  0.000000 ######
#    13.                                 "age"  0.000000 ######
#    14.                        "height_in_cm" -0.004098 ####
#    15.                          "hematocrit" -0.004098 ####
#    16.                        "nicotine_use" -0.004098 ####
#    17.         "alkaline_phosphatase_in_u_l" -0.004098 ####
#    18.              "triglycerides_in_mg_dl" -0.004098 ####
#    19.                      "got_ast_in_u_l" -0.008197 ##
#    20.                       "gfr_in_ml_min" -0.008197 ##
#    21.                        "weight_in_kg" -0.008197 ##
#    22.                 "creatinine_in_mg_dl" -0.012295
#
# Variable Importance: MEAN_DECREASE_IN_AP_2_VS_OTHERS:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.217492 ################
#     2.                                 "age"  0.055736 ####
#     3.                          "hematocrit"  0.017361 #
#     4.                       "lipase_in_u_l"  0.017107 #
#     5.                        "crp_in_mg_dl"  0.015633 #
#     6.                     "gamma-gt_in_u_l"  0.011120 #
#     7.                                 "inr"  0.008071 #
#     8.                         "alcohol_use"  0.006856 #
#     9.              "triglycerides_in_mg_dl"  0.006344 #
#    10.                  "bilirubin_in_mg_dl"  0.006024 #
#    11.                   "leukocytes_in_g_l"  0.005377 #
#    12.                                 "sex"  0.002946
#    13.                   "calcium_in_mmol_l"  0.002266
#    14.                 "creatinine_in_mg_dl"  0.001645
#    15.                      "gpt_alt_in_u_l"  0.000524
#    16.                        "height_in_cm"  0.000021
#    17.                       "gfr_in_ml_min" -0.000753
#    18.                        "weight_in_kg" -0.001226
#    19.                        "nicotine_use" -0.001455
#    20.                       "urea_in_mg_dl" -0.002223
#    21.                      "got_ast_in_u_l" -0.003639
#    22.         "alkaline_phosphatase_in_u_l" -0.008802
#
# Variable Importance: MEAN_DECREASE_IN_AUC_2_VS_OTHERS:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.143585 ################
#     2.                        "crp_in_mg_dl"  0.022386 ##
#     3.                                 "inr"  0.011123 #
#     4.                   "calcium_in_mmol_l"  0.009872 #
#     5.                          "hematocrit"  0.009501 #
#     6.                                 "age"  0.006999 #
#     7.                  "bilirubin_in_mg_dl"  0.006118 #
#     8.                        "height_in_cm"  0.005515 #
#     9.                   "leukocytes_in_g_l"  0.003940 #
#    10.                        "weight_in_kg"  0.003893
#    11.                      "got_ast_in_u_l"  0.003708
#    12.                         "alcohol_use"  0.003615
#    13.                       "gfr_in_ml_min"  0.003291
#    14.                 "creatinine_in_mg_dl"  0.003059
#    15.              "triglycerides_in_mg_dl"  0.002225
#    16.                       "urea_in_mg_dl"  0.001298
#    17.                                 "sex"  0.000649
#    18.                       "lipase_in_u_l"  0.000185
#    19.                      "gpt_alt_in_u_l" -0.001437
#    20.                     "gamma-gt_in_u_l" -0.001947
#    21.                        "nicotine_use" -0.002827
#    22.         "alkaline_phosphatase_in_u_l" -0.005376
#
# Variable Importance: MEAN_DECREASE_IN_PRAUC_2_VS_OTHERS:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm"  0.218489 ################
#     2.                                 "age"  0.056089 ####
#     3.                          "hematocrit"  0.017225 #
#     4.                        "crp_in_mg_dl"  0.015496 #
#     5.                       "lipase_in_u_l"  0.013584 #
#     6.                     "gamma-gt_in_u_l"  0.009612 #
#     7.                                 "inr"  0.006507 #
#     8.                   "calcium_in_mmol_l"  0.006365 #
#     9.                         "alcohol_use"  0.006219 #
#    10.              "triglycerides_in_mg_dl"  0.005570 #
#    11.                  "bilirubin_in_mg_dl"  0.004726
#    12.                   "leukocytes_in_g_l"  0.004131
#    13.                                 "sex"  0.002771
#    14.                 "creatinine_in_mg_dl"  0.000484
#    15.                      "gpt_alt_in_u_l" -0.000644
#    16.                        "height_in_cm" -0.000672
#    17.                       "gfr_in_ml_min" -0.001086
#    18.                        "weight_in_kg" -0.001502
#    19.                        "nicotine_use" -0.001826
#    20.                       "urea_in_mg_dl" -0.003702
#    21.                      "got_ast_in_u_l" -0.004754
#    22.         "alkaline_phosphatase_in_u_l" -0.009021
#
# Variable Importance: NUM_AS_ROOT:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm" 79.000000 ################
#     2.                                 "age" 38.000000 #######
#     3.                   "calcium_in_mmol_l" 36.000000 #######
#     4.                        "height_in_cm" 35.000000 ######
#     5.                        "crp_in_mg_dl" 18.000000 ###
#     6.         "alkaline_phosphatase_in_u_l" 15.000000 ##
#     7.                     "gamma-gt_in_u_l" 14.000000 ##
#     8.                          "hematocrit" 13.000000 ##
#     9.                        "weight_in_kg" 12.000000 ##
#    10.                                 "inr" 10.000000 #
#    11.                      "got_ast_in_u_l"  8.000000 #
#    12.              "triglycerides_in_mg_dl"  7.000000 #
#    13.                  "bilirubin_in_mg_dl"  4.000000
#    14.                 "creatinine_in_mg_dl"  3.000000
#    15.                   "leukocytes_in_g_l"  3.000000
#    16.                       "gfr_in_ml_min"  2.000000
#    17.                      "gpt_alt_in_u_l"  2.000000
#    18.                       "lipase_in_u_l"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm" 556.000000 ################
#     2.                   "calcium_in_mmol_l" 408.000000 ###########
#     3.                                 "age" 369.000000 ##########
#     4.                        "height_in_cm" 330.000000 #########
#     5.                          "hematocrit" 317.000000 ########
#     6.                       "lipase_in_u_l" 310.000000 ########
#     7.                        "crp_in_mg_dl" 302.000000 ########
#     8.         "alkaline_phosphatase_in_u_l" 298.000000 ########
#     9.                   "leukocytes_in_g_l" 296.000000 ########
#    10.                        "weight_in_kg" 296.000000 ########
#    11.                      "got_ast_in_u_l" 295.000000 ########
#    12.              "triglycerides_in_mg_dl" 268.000000 #######
#    13.                       "urea_in_mg_dl" 261.000000 #######
#    14.                  "bilirubin_in_mg_dl" 238.000000 ######
#    15.                      "gpt_alt_in_u_l" 238.000000 ######
#    16.                     "gamma-gt_in_u_l" 233.000000 ######
#    17.                       "gfr_in_ml_min" 202.000000 #####
#    18.                                 "inr" 200.000000 #####
#    19.                 "creatinine_in_mg_dl" 166.000000 ####
#    20.                         "alcohol_use" 65.000000 #
#    21.                        "nicotine_use" 59.000000
#    22.                                 "sex" 26.000000
#
# Variable Importance: SUM_SCORE:
#     1. "eus_ercp_mrcp_or_as_dhc_width_in_mm" 5901.566754 ################
#     2.                   "calcium_in_mmol_l" 2343.652594 ######
#     3.                                 "age" 2060.503928 #####
#     4.                        "height_in_cm" 1839.967955 ####
#     5.                          "hematocrit" 1549.157974 ####
#     6.                        "crp_in_mg_dl" 1547.824468 ####
#     7.                       "lipase_in_u_l" 1474.532189 ###
#     8.                      "got_ast_in_u_l" 1369.363230 ###
#     9.                        "weight_in_kg" 1363.778723 ###
#    10.         "alkaline_phosphatase_in_u_l" 1351.465344 ###
#    11.                   "leukocytes_in_g_l" 1290.433637 ###
#    12.              "triglycerides_in_mg_dl" 1231.713634 ###
#    13.                       "urea_in_mg_dl" 1174.474990 ###
#    14.                  "bilirubin_in_mg_dl" 1070.378753 ##
#    15.                     "gamma-gt_in_u_l" 1008.661370 ##
#    16.                      "gpt_alt_in_u_l" 1001.332846 ##
#    17.                                 "inr" 901.021298 ##
#    18.                       "gfr_in_ml_min" 866.718827 ##
#    19.                 "creatinine_in_mg_dl" 715.439580 #
#    20.                         "alcohol_use" 281.044473
#    21.                        "nicotine_use" 241.191353
#    22.                                 "sex" 79.772901
#
#
#
# Winner takes all: true
# Out-of-bag evaluation: accuracy:0.77459 logloss:0.455304
# Number of trees: 300
# Total number of nodes: 11766
#
# Number of nodes by tree:
# Count: 300 Average: 39.22 StdDev: 4.1527
# Min: 29 Max: 53 Ignored: 0
# ----------------------------------------------
# [ 29, 30)  4   1.33%   1.33% #
# [ 30, 31)  0   0.00%   1.33%
# [ 31, 32) 11   3.67%   5.00% ##
# [ 32, 34) 19   6.33%  11.33% ###
# [ 34, 35)  0   0.00%  11.33%
# [ 35, 36) 27   9.00%  20.33% ####
# [ 36, 37)  0   0.00%  20.33%
# [ 37, 39) 45  15.00%  35.33% #######
# [ 39, 40) 67  22.33%  57.67% ##########
# [ 40, 41)  0   0.00%  57.67%
# [ 41, 42) 58  19.33%  77.00% #########
# [ 42, 44) 37  12.33%  89.33% ######
# [ 44, 45)  0   0.00%  89.33%
# [ 45, 46) 17   5.67%  95.00% ###
# [ 46, 47)  0   0.00%  95.00%
# [ 47, 49)  8   2.67%  97.67% #
# [ 49, 50)  5   1.67%  99.33% #
# [ 50, 51)  0   0.00%  99.33%
# [ 51, 52)  1   0.33%  99.67%
# [ 52, 53]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 6033 Average: 5.40046 StdDev: 1.90859
# Min: 1 Max: 13 Ignored: 0
# ----------------------------------------------
# [  1,  2)   56   0.93%   0.93%
# [  2,  3)  214   3.55%   4.48% ##
# [  3,  4)  679  11.25%  15.73% #####
# [  4,  5) 1086  18.00%  33.73% #########
# [  5,  6) 1266  20.98%  54.72% ##########
# [  6,  7) 1137  18.85%  73.56% #########
# [  7,  8)  798  13.23%  86.79% ######
# [  8,  9)  414   6.86%  93.65% ###
# [  9, 10)  230   3.81%  97.46% ##
# [ 10, 11)  102   1.69%  99.15% #
# [ 11, 12)   38   0.63%  99.78%
# [ 12, 13)   11   0.18%  99.97%
# [ 13, 13]    2   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 6033 Average: 12.1333 StdDev: 13.5725
# Min: 5 Max: 118 Ignored: 0
# ----------------------------------------------
# [   5,  10) 4239  70.26%  70.26% ##########
# [  10,  16)  711  11.79%  82.05% ##
# [  16,  22)  331   5.49%  87.54% #
# [  22,  27)  161   2.67%  90.20%
# [  27,  33)  137   2.27%  92.47%
# [  33,  39)  101   1.67%  94.15%
# [  39,  44)   70   1.16%  95.31%
# [  44,  50)   65   1.08%  96.39%
# [  50,  56)   46   0.76%  97.15%
# [  56,  62)   48   0.80%  97.94%
# [  62,  67)   32   0.53%  98.48%
# [  67,  73)   29   0.48%  98.96%
# [  73,  79)   25   0.41%  99.37%
# [  79,  84)    9   0.15%  99.52%
# [  84,  90)   15   0.25%  99.77%
# [  90,  96)    5   0.08%  99.85%
# [  96, 101)    4   0.07%  99.92%
# [ 101, 107)    2   0.03%  99.95%
# [ 107, 113)    1   0.02%  99.97%
# [ 113, 118]    2   0.03% 100.00%
#
# Attribute in nodes:
# 	556 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	408 : calcium_in_mmol_l [NUMERICAL]
# 	369 : age [NUMERICAL]
# 	330 : height_in_cm [NUMERICAL]
# 	317 : hematocrit [NUMERICAL]
# 	310 : lipase_in_u_l [NUMERICAL]
# 	302 : crp_in_mg_dl [NUMERICAL]
# 	298 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	296 : weight_in_kg [NUMERICAL]
# 	296 : leukocytes_in_g_l [NUMERICAL]
# 	295 : got_ast_in_u_l [NUMERICAL]
# 	268 : triglycerides_in_mg_dl [NUMERICAL]
# 	261 : urea_in_mg_dl [NUMERICAL]
# 	238 : gpt_alt_in_u_l [NUMERICAL]
# 	238 : bilirubin_in_mg_dl [NUMERICAL]
# 	233 : gamma-gt_in_u_l [NUMERICAL]
# 	202 : gfr_in_ml_min [NUMERICAL]
# 	200 : inr [NUMERICAL]
# 	166 : creatinine_in_mg_dl [NUMERICAL]
# 	65 : alcohol_use [NUMERICAL]
# 	59 : nicotine_use [NUMERICAL]
# 	26 : sex [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	79 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	38 : age [NUMERICAL]
# 	36 : calcium_in_mmol_l [NUMERICAL]
# 	35 : height_in_cm [NUMERICAL]
# 	18 : crp_in_mg_dl [NUMERICAL]
# 	15 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	14 : gamma-gt_in_u_l [NUMERICAL]
# 	13 : hematocrit [NUMERICAL]
# 	12 : weight_in_kg [NUMERICAL]
# 	10 : inr [NUMERICAL]
# 	8 : got_ast_in_u_l [NUMERICAL]
# 	7 : triglycerides_in_mg_dl [NUMERICAL]
# 	4 : bilirubin_in_mg_dl [NUMERICAL]
# 	3 : leukocytes_in_g_l [NUMERICAL]
# 	3 : creatinine_in_mg_dl [NUMERICAL]
# 	2 : gpt_alt_in_u_l [NUMERICAL]
# 	2 : gfr_in_ml_min [NUMERICAL]
# 	1 : lipase_in_u_l [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	172 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	84 : calcium_in_mmol_l [NUMERICAL]
# 	78 : age [NUMERICAL]
# 	76 : height_in_cm [NUMERICAL]
# 	48 : crp_in_mg_dl [NUMERICAL]
# 	42 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	40 : hematocrit [NUMERICAL]
# 	36 : weight_in_kg [NUMERICAL]
# 	33 : leukocytes_in_g_l [NUMERICAL]
# 	31 : got_ast_in_u_l [NUMERICAL]
# 	29 : inr [NUMERICAL]
# 	29 : gamma-gt_in_u_l [NUMERICAL]
# 	25 : lipase_in_u_l [NUMERICAL]
# 	24 : triglycerides_in_mg_dl [NUMERICAL]
# 	24 : gpt_alt_in_u_l [NUMERICAL]
# 	18 : urea_in_mg_dl [NUMERICAL]
# 	18 : creatinine_in_mg_dl [NUMERICAL]
# 	16 : bilirubin_in_mg_dl [NUMERICAL]
# 	14 : gfr_in_ml_min [NUMERICAL]
# 	3 : nicotine_use [NUMERICAL]
# 	3 : alcohol_use [NUMERICAL]
# 	1 : sex [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	259 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	140 : calcium_in_mmol_l [NUMERICAL]
# 	137 : age [NUMERICAL]
# 	134 : height_in_cm [NUMERICAL]
# 	92 : hematocrit [NUMERICAL]
# 	90 : crp_in_mg_dl [NUMERICAL]
# 	86 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	82 : leukocytes_in_g_l [NUMERICAL]
# 	79 : weight_in_kg [NUMERICAL]
# 	76 : lipase_in_u_l [NUMERICAL]
# 	69 : got_ast_in_u_l [NUMERICAL]
# 	65 : triglycerides_in_mg_dl [NUMERICAL]
# 	59 : gamma-gt_in_u_l [NUMERICAL]
# 	59 : bilirubin_in_mg_dl [NUMERICAL]
# 	58 : inr [NUMERICAL]
# 	58 : gpt_alt_in_u_l [NUMERICAL]
# 	52 : gfr_in_ml_min [NUMERICAL]
# 	50 : urea_in_mg_dl [NUMERICAL]
# 	47 : creatinine_in_mg_dl [NUMERICAL]
# 	12 : nicotine_use [NUMERICAL]
# 	10 : alcohol_use [NUMERICAL]
# 	4 : sex [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	346 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	221 : calcium_in_mmol_l [NUMERICAL]
# 	207 : age [NUMERICAL]
# 	199 : height_in_cm [NUMERICAL]
# 	156 : hematocrit [NUMERICAL]
# 	143 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	142 : leukocytes_in_g_l [NUMERICAL]
# 	138 : crp_in_mg_dl [NUMERICAL]
# 	137 : weight_in_kg [NUMERICAL]
# 	134 : lipase_in_u_l [NUMERICAL]
# 	129 : got_ast_in_u_l [NUMERICAL]
# 	116 : triglycerides_in_mg_dl [NUMERICAL]
# 	105 : bilirubin_in_mg_dl [NUMERICAL]
# 	101 : inr [NUMERICAL]
# 	101 : gamma-gt_in_u_l [NUMERICAL]
# 	100 : gpt_alt_in_u_l [NUMERICAL]
# 	91 : urea_in_mg_dl [NUMERICAL]
# 	84 : gfr_in_ml_min [NUMERICAL]
# 	77 : creatinine_in_mg_dl [NUMERICAL]
# 	25 : alcohol_use [NUMERICAL]
# 	24 : nicotine_use [NUMERICAL]
# 	11 : sex [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	474 : eus_ercp_mrcp_or_as_dhc_width_in_mm [NUMERICAL]
# 	340 : calcium_in_mmol_l [NUMERICAL]
# 	314 : age [NUMERICAL]
# 	270 : height_in_cm [NUMERICAL]
# 	256 : lipase_in_u_l [NUMERICAL]
# 	256 : hematocrit [NUMERICAL]
# 	252 : alkaline_phosphatase_in_u_l [NUMERICAL]
# 	248 : crp_in_mg_dl [NUMERICAL]
# 	242 : got_ast_in_u_l [NUMERICAL]
# 	235 : leukocytes_in_g_l [NUMERICAL]
# 	234 : weight_in_kg [NUMERICAL]
# 	219 : triglycerides_in_mg_dl [NUMERICAL]
# 	201 : urea_in_mg_dl [NUMERICAL]
# 	191 : gpt_alt_in_u_l [NUMERICAL]
# 	189 : bilirubin_in_mg_dl [NUMERICAL]
# 	188 : gamma-gt_in_u_l [NUMERICAL]
# 	161 : inr [NUMERICAL]
# 	160 : gfr_in_ml_min [NUMERICAL]
# 	133 : creatinine_in_mg_dl [NUMERICAL]
# 	50 : alcohol_use [NUMERICAL]
# 	46 : nicotine_use [NUMERICAL]
# 	18 : sex [NUMERICAL]
#
# Condition type in nodes:
# 	5733 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	844 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	1718 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	2787 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	4677 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.767442 logloss:8.38224
# 	trees: 11, Out-of-bag evaluation: accuracy:0.737705 logloss:3.69898
# 	trees: 21, Out-of-bag evaluation: accuracy:0.741803 logloss:3.70446
# 	trees: 31, Out-of-bag evaluation: accuracy:0.770492 logloss:1.99364
# 	trees: 49, Out-of-bag evaluation: accuracy:0.782787 logloss:0.877043
# 	trees: 66, Out-of-bag evaluation: accuracy:0.77459 logloss:0.457708
# 	trees: 78, Out-of-bag evaluation: accuracy:0.795082 logloss:0.467283
# 	trees: 90, Out-of-bag evaluation: accuracy:0.790984 logloss:0.464115
# 	trees: 100, Out-of-bag evaluation: accuracy:0.795082 logloss:0.461738
# 	trees: 110, Out-of-bag evaluation: accuracy:0.795082 logloss:0.462193
# 	trees: 121, Out-of-bag evaluation: accuracy:0.786885 logloss:0.462452
# 	trees: 138, Out-of-bag evaluation: accuracy:0.790984 logloss:0.453307
# 	trees: 153, Out-of-bag evaluation: accuracy:0.786885 logloss:0.456613
# 	trees: 165, Out-of-bag evaluation: accuracy:0.77459 logloss:0.456832
# 	trees: 179, Out-of-bag evaluation: accuracy:0.778689 logloss:0.457374
# 	trees: 189, Out-of-bag evaluation: accuracy:0.766393 logloss:0.459438
# 	trees: 200, Out-of-bag evaluation: accuracy:0.77459 logloss:0.457705
# 	trees: 210, Out-of-bag evaluation: accuracy:0.770492 logloss:0.455157
# 	trees: 220, Out-of-bag evaluation: accuracy:0.770492 logloss:0.455359
# 	trees: 234, Out-of-bag evaluation: accuracy:0.770492 logloss:0.451948
# 	trees: 245, Out-of-bag evaluation: accuracy:0.77459 logloss:0.453358
# 	trees: 255, Out-of-bag evaluation: accuracy:0.770492 logloss:0.455123
# 	trees: 265, Out-of-bag evaluation: accuracy:0.770492 logloss:0.455681
# 	trees: 275, Out-of-bag evaluation: accuracy:0.770492 logloss:0.45562
# 	trees: 285, Out-of-bag evaluation: accuracy:0.770492 logloss:0.454501
# 	trees: 300, Out-of-bag evaluation: accuracy:0.77459 logloss:0.455304
#
# dict_keys(['INV_MEAN_MIN_DEPTH', 'SUM_SCORE', 'NUM_NODES', 'MEAN_DECREASE_IN_ACCURACY', 'MEAN_DECREASE_IN_AP_2_VS_OTHERS', 'MEAN_DECREASE_IN_AUC_2_VS_OTHERS', 'MEAN_DECREASE_IN_PRAUC_2_VS_OTHERS', 'NUM_AS_ROOT'])
# [("eus_ercp_mrcp_or_as_dhc_width_in_mm" (1; #8), 0.016393423080444336),
#  ("calcium_in_mmol_l" (1; #5), 0.008196711540222168),
#  ("bilirubin_in_mg_dl" (1; #4), 0.004098355770111084),
#  ("inr" (1; #15), 0.004098355770111084),
#  ("gpt_alt_in_u_l" (1; #12), 0.004098355770111084),
#  ("alcohol_use" (1; #2), 0.0),
#  ("urea_in_mg_dl" (1; #21), 0.0),
#  ("sex" (1; #19), 0.0),
#  ("lipase_in_u_l" (1; #17), 0.0),
#  ("leukocytes_in_g_l" (1; #16), 0.0),
#  ("gamma-gt_in_u_l" (1; #9), 0.0),
#  ("crp_in_mg_dl" (1; #7), 0.0),
#  ("age" (1; #1), 0.0),
#  ("height_in_cm" (1; #13), -0.004098415374755859),
#  ("hematocrit" (1; #14), -0.004098415374755859),
#  ("nicotine_use" (1; #18), -0.004098415374755859),
#  ("alkaline_phosphatase_in_u_l" (1; #3), -0.004098415374755859),
#  ("triglycerides_in_mg_dl" (1; #20), -0.004098415374755859),
#  ("got_ast_in_u_l" (1; #11), -0.008196771144866943),
#  ("gfr_in_ml_min" (1; #10), -0.008196771144866943),
#  ("weight_in_kg" (1; #22), -0.008196771144866943),
#  ("creatinine_in_mg_dl" (1; #6), -0.012295126914978027)]

# %%
print(f"Available variable importances:")
for importance in inspector.variable_importances().keys():
  print("\t", importance)
# Out:
# Available variable importances:
# 	 INV_MEAN_MIN_DEPTH
# 	 SUM_SCORE
# 	 NUM_NODES
# 	 MEAN_DECREASE_IN_ACCURACY
# 	 MEAN_DECREASE_IN_AP_2_VS_OTHERS
# 	 MEAN_DECREASE_IN_AUC_2_VS_OTHERS
# 	 MEAN_DECREASE_IN_PRAUC_2_VS_OTHERS
# 	 NUM_AS_ROOT

# %% [markdown]
# #### Plot feature importance
# Report feature importance as Inverse mean minimum depth (INV_MEAN_MIN_DEPTH).

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 4))

# Mean decrease in AUC of the class 1 vs the others.
variable_importance_metric = "INV_MEAN_MIN_DEPTH"
variable_importances = inspector.variable_importances()[variable_importance_metric]

# Extract the feature name and importance values.
#
# `variable_importances` is a list of <feature, importance> tuples.
feature_names = [vi[0].name for vi in variable_importances]
feature_importances = [vi[1] for vi in variable_importances]
# The feature are ordered in decreasing importance value.
feature_ranks = range(len(feature_names))

bar = plt.barh(feature_ranks, feature_importances, label=[str(x) for x in feature_ranks])
plt.yticks(feature_ranks, feature_names)
plt.gca().invert_yaxis()

# TODO: Replace with "plt.bar_label()" when available.
# Label each bar with values
for importance, patch in zip(feature_importances, bar.patches):
  plt.text(patch.get_x() + patch.get_width(), patch.get_y(), f"{importance:.4f}", va="top")

plt.xlabel(variable_importance_metric)
plt.title("INV_MEAN_MIN_DEPTH")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Write feature importances to csv

# %%
df = pd.DataFrame()
df['feature_names'] = feature_names
df['feature_importances'] = feature_importances
df['feature_ranks'] = feature_ranks
df['variable_importance_metric'] = variable_importance_metric

# Add feature type (numeric or categorical) by checing, if feature name is in part in CATEGORICAL_FEATURE_NAMES
df['feature_type'] = 'numeric'
df['feature_type'] = np.where(df['feature_names'].str.contains('|'.join(CATEGORICAL_FEATURE_NAMES)), 'categorical', 'numeric')
# check for each name in df['feature_names'] if it is a substring of CATEGORICAL_FEATURE_NAMES
for i in df['feature_names']:
    i in ('|'.join(CATEGORICAL_FEATURE_NAMES))
    if i in ('|'.join(CATEGORICAL_FEATURE_NAMES)):
        df.loc[df['feature_names'] == i, 'feature_type'] = 'categorical'
df.to_csv("data/feature_importances.csv", index=False)

# %% [markdown]
# #### Plot the model

# %%
# Tell dtreeviz about training data and model
model_features = [f.name for f in model_rf.make_inspector().features()]

model_features
classes = [0, 1]

train_df_pd['has_idc'] = train_df_pd['has_idc'].astype(int)

viz_cmodel = dtreeviz.model(model_rf,
                           tree_index=3,
                           X_train=train_df_pd[model_features],
                           y_train=train_df_pd['has_idc'],
                           feature_names=model_features,
                           target_name=TARGET_COLUMN_NAME,
                           class_names=classes)

# %% [markdown]
# ##### Plot of complete model

# %%
viz_cmodel.view()

# %% [markdown]
# ##### First three levels of tree

# %%
viz_cmodel.view(depth_range_to_display=[0,2])

# %% [markdown]
# ##### Other plots

# %%
x = train_df_pd[model_features].iloc[0]
viz_cmodel.view(x=x, show_just_path=True, scale=.75)
# Out:
# /opt/conda/lib/python3.11/site-packages/dtreeviz/models/shadow_decision_tree.py:335: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /opt/conda/lib/python3.11/site-packages/dtreeviz/trees.py:1231: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
# /opt/conda/lib/python3.11/site-packages/dtreeviz/trees.py:420: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`

# %%
train_df_pd.iloc[0]
# Out:
# has_idc                                         1.000000
# sex                                             1.000000
# nicotine_use                                    1.000000
# alcohol_use                                     1.000000
# age                                            57.000000
# height_in_cm                                  170.000000
# weight_in_kg                                  110.000000
# eus_ercp_mrcp_or_as_dhc_width_in_mm             5.000000
# crp_in_mg_dl                                    1.000000
# leukocytes_in_g_l                               4.790000
# bilirubin_in_mg_dl                             18.600000
# got_ast_in_u_l                                 85.568164
# gpt_alt_in_u_l                                 59.000000
# gamma-gt_in_u_l                               110.000000
# alkaline_phosphatase_in_u_l                   134.000000
# lipase_in_u_l                                3960.000000
# inr                                             1.700000
# calcium_in_mmol_l                               2.080000
# triglycerides_in_mg_dl                         66.000000
# hematocrit                                      0.367000
# gfr_in_ml_min                                  93.000000
# creatinine_in_mg_dl                             1.100000
# urea_in_mg_dl                                  30.450703
# clinical_data_stone_microlithiasis_sludge       2.000000
# Name: 0, dtype: float64

# %%
viz_cmodel.view(depth_range_to_display=[3,3], scale=1.5)

# %% [markdown]
# #### Plot the training logs

# %%
import matplotlib.pyplot as plt

logs = model_rf.make_inspector().training_logs()

plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot([log.num_trees for log in logs], [log.evaluation.accuracy for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Accuracy (out-of-bag)")

plt.subplot(1, 2, 2)
plt.plot([log.num_trees for log in logs], [log.evaluation.loss for log in logs])
plt.xlabel("Number of trees")
plt.ylabel("Logloss (out-of-bag)")

plt.show()

# %% [markdown]
# ## Test data for TFDF: Day 3

# %% [markdown]
# ### Features

# %% [markdown]
# #### Test the model on day 3

# %%
test_df_ecrp_gte_3_days.values
# Out:
# array([[ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True]])

# %%
# Subset test_df_d3 for only preds == True and ecrp_gte_3_days == True
d3 = test_df_ecrp_gte_3_days.values
tp = (np.logical_and(d3 == True, preds == False))
test_df_d32_keras = tfdf.keras.pd_dataframe_to_tf_dataset(test_df_d32[tp], label="has_idc")


probs_d3 = model_rf.predict(test_df_d32_keras)

probs_d3 = probs_d3 > 0.3

probs_d3 = probs_d3.astype(int)


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
confusion_matrix(test_labels[tp], probs_d3)




import matplotlib.pyplot as plt

cm = confusion_matrix(test_labels[tp], probs_d3)

disp = ConfusionMatrixDisplay(cm)
disp.plot()
plt.show()
# Out:
# 1/1 [==============================] - 0s 47ms/step

# %% [markdown]
# **Figure.** This figure shows the patients who did not receive an ERCP within 3 days of admission and who were classfied as 'no IDC' on admission. Note: the number of cases with IDC is very low!

# %%
evaluation = model_rf.evaluate(test_df_d32_keras, return_dict=True)
for name, value in evaluation.items():
  print(f"{name}: {value:.4f}")
# Out:
# 1/1 [==============================] - 0s 203ms/step - loss: 0.0000e+00 - accuracy: 0.9630 - auc: 0.6154 - true_positives: 0.0000e+00 - true_negatives: 26.0000 - false_positives: 0.0000e+00 - false_negatives: 1.0000
# loss: 0.0000
# accuracy: 0.9630
# auc: 0.6154
# true_positives: 0.0000
# true_negatives: 26.0000
# false_positives: 0.0000
# false_negatives: 1.0000
